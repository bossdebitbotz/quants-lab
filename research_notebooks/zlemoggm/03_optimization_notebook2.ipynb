# %%
# This is necessary to recognize the modules
import os
import sys
import warnings
import optuna

from optuna.storages import RDBStorage  # Add this import

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
# Database configuration
DB_CONFIG = {
    'host': 'localhost',
    'port': 5438,
    'user': 'backtest_user',
    'password': 'backtest_password',
    'database': 'backtest_db'
}

# Create the connection string
storage_url = f"postgresql://{DB_CONFIG['user']}:{DB_CONFIG['password']}@{DB_CONFIG['host']}:{DB_CONFIG['port']}/{DB_CONFIG['database']}"

# Initialize storage with conservative settings
storage = RDBStorage(
    storage_url,
)

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer
from research_notebooks.zlemoggm.zlemog_config_gen_simple import ZLEMAConfigGenerator
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 import datetime
# ----> 2 from core.backtesting.optimizer import StrategyOptimizer
#       3 from research_notebooks.zlemoggm.zlemog_config_gen_simple import ZLEMAConfigGenerator
#
# File /Volumes/Elite_Frosty /quants-lab/core/backtesting/__init__.py:1
# ----> 1 from .engine import BacktestingEngine
#       3 __all__ = ["BacktestingEngine"]
#
# File /Volumes/Elite_Frosty /quants-lab/core/backtesting/engine.py:7
#       3 from typing import Dict, Optional
#       5 import pandas as pd
# ----> 7 from core.data_structures.backtesting_result import BacktestingResult
#       8 from hummingbot.strategy_v2.backtesting.backtesting_engine_base import BacktestingEngineBase
#       9 from hummingbot.strategy_v2.controllers import ControllerConfigBase
#
# File /Volumes/Elite_Frosty /quants-lab/core/data_structures/backtesting_result.py:11
#       9 from core.data_structures.data_structure_base import DataStructureBase
#      10 from hummingbot.connector.connector_base import TradeType
# ---> 11 from hummingbot.strategy_v2.controllers import ControllerConfigBase
#      14 class BacktestingResult(DataStructureBase):
#      15     def __init__(self, backtesting_result: Dict, controller_config: ControllerConfigBase):
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/controllers/__init__.py:2
#       1 from hummingbot.strategy_v2.controllers.controller_base import ControllerBase, ControllerConfigBase
# ----> 2 from hummingbot.strategy_v2.controllers.directional_trading_controller_base import (
#       3     DirectionalTradingControllerBase,
#       4     DirectionalTradingControllerConfigBase,
#       5 )
#       6 from hummingbot.strategy_v2.controllers.market_making_controller_base import (
#       7     MarketMakingControllerBase,
#       8     MarketMakingControllerConfigBase,
#       9 )
#      11 __all__ = [
#      12     "ControllerBase",
#      13     "ControllerConfigBase",
#    (...)
#      17     "MarketMakingControllerConfigBase",
#      18 ]
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/controllers/directional_trading_controller_base.py:8
#       5 from pydantic import Field, validator
#       7 from hummingbot.client.config.config_data_types import ClientFieldData
# ----> 8 from hummingbot.client.ui.interface_utils import format_df_for_printout
#       9 from hummingbot.core.data_type.common import OrderType, PositionMode, PriceType, TradeType
#      10 from hummingbot.strategy_v2.controllers.controller_base import ControllerBase, ControllerConfigBase
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/client/ui/__init__.py:10
#       7 from prompt_toolkit.styles import Style
#       9 from hummingbot import root_path
# ---> 10 from hummingbot.client.config.conf_migration import migrate_configs, migrate_non_secure_configs_only
#      11 from hummingbot.client.config.config_crypt import BaseSecretsManager, store_password_verification
#      12 from hummingbot.client.config.security import Security
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/client/config/conf_migration.py:24
#      11 from hummingbot import root_path
#      12 from hummingbot.client.config.client_config_map import (
#      13     AnonymizedMetricsDisabledMode,
#      14     AnonymizedMetricsEnabledMode,
#    (...)
#      22     TelegramEnabledMode,
#      23 )
# ---> 24 from hummingbot.client.config.config_crypt import BaseSecretsManager, store_password_verification
#      25 from hummingbot.client.config.config_data_types import BaseConnectorConfigMap
#      26 from hummingbot.client.config.config_helpers import ClientConfigAdapter, save_to_yml
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/client/config/config_crypt.py:5
#       2 import json
#       3 from abc import ABC, abstractmethod
# ----> 5 from eth_account import Account
#       6 from eth_keyfile.keyfile import (
#       7     DKLEN,
#       8     SCRYPT_P,
#    (...)
#      18     keccak,
#      19 )
#      20 from pydantic import SecretStr
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/eth_account/__init__.py:5
#       1 from importlib.metadata import (
#       2     version as __version,
#       3 )
# ----> 5 from eth_account.account import (
#       6     Account,
#       7 )
#       9 __all__ = ["Account"]
#      11 __version__ = __version("eth-account")
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/eth_account/account.py:17
#       6 from typing import (
#       7     Any,
#       8     Dict,
#    (...)
#      13     cast,
#      14 )
#      15 import warnings
# ---> 17 from eth_keyfile import (
#      18     create_keyfile_json,
#      19     decode_keyfile_json,
#      20 )
#      21 from eth_keys import (
#      22     KeyAPI,
#      23     keys,
#      24 )
#      25 from eth_keys.exceptions import (
#      26     ValidationError,
#      27 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/eth_keyfile/__init__.py:5
#       1 from importlib.metadata import (
#       2     version as __version,
#       3 )
# ----> 5 from eth_keyfile.keyfile import (
#       6     create_keyfile_json,
#       7     decode_keyfile_json,
#       8     extract_key_from_keyfile,
#       9     load_keyfile,
#      10 )
#      12 __version__ = __version("eth-keyfile")
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/eth_keyfile/keyfile.py:56
#      41 from eth_typing import (
#      42     HexStr,
#      43 )
#      44 from eth_utils import (
#      45     big_endian_to_int,
#      46     decode_hex,
#    (...)
#      54     to_int,
#      55 )
# ---> 56 from py_ecc.bls12_381 import (
#      57     curve_order,
#      58 )
#      59 from py_ecc.bls import (
#      60     G2ProofOfPossession as bls,
#      61 )
#      62 from py_ecc.secp256k1 import (
#      63     N,
#      64 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/__init__.py:6
#       1 from importlib.metadata import (
#       2     version as __version,
#       3 )
#       4 import sys
# ----> 6 from py_ecc import (
#       7     bls,
#       8     bls12_381,
#       9     bn128,
#      10     optimized_bls12_381,
#      11     optimized_bn128,
#      12     secp256k1,
#      13 )
#      15 sys.setrecursionlimit(max(100000, sys.getrecursionlimit()))
#      17 __version__ = __version("py_ecc")
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/bls/__init__.py:1
# ----> 1 from .ciphersuites import (
#       2     G2Basic,
#       3     G2MessageAugmentation,
#       4     G2ProofOfPossession,
#       5 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/bls/ciphersuites.py:24
#      17 from eth_utils import (
#      18     ValidationError,
#      19 )
#      21 from py_ecc.fields import (
#      22     optimized_bls12_381_FQ12 as FQ12,
#      23 )
# ---> 24 from py_ecc.optimized_bls12_381 import (
#      25     G1,
#      26     Z1,
#      27     Z2,
#      28     add,
#      29     curve_order,
#      30     final_exponentiate,
#      31     multiply,
#      32     neg,
#      33     pairing,
#      34 )
#      36 from .g2_primitives import (
#      37     G1_to_pubkey,
#      38     G2_to_signature,
#    (...)
#      42     subgroup_check,
#      43 )
#      44 from .hash import (
#      45     hkdf_expand,
#      46     hkdf_extract,
#      47     i2osp,
#      48     os2ip,
#      49 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/optimized_bls12_381/__init__.py:32
#       8 from .optimized_clear_cofactor import (
#       9     multiply_clear_cofactor_G2,
#      10 )
#      11 from .optimized_curve import (
#      12     G1,
#      13     G2,
#    (...)
#      30     twist,
#      31 )
# ---> 32 from .optimized_pairing import (
#      33     final_exponentiate,
#      34     pairing,
#      35 )
#      36 from .optimized_swu import (
#      37     iso_map_G2,
#      38     optimized_swu_G2,
#      39 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/optimized_bls12_381/optimized_pairing.py:225
#     221         return FQ12.one()
#     222     return miller_loop(Q, P, final_exponentiate=final_exponentiate)
# --> 225 exptable = [FQ12([0] * i + [1] + [0] * (11 - i)) ** field_modulus for i in range(12)]
#     228 def exp_by_p(x: FQ12) -> FQ12:
#     229     return sum(
#     230         (table_entry * coeff for table_entry, coeff in zip(exptable, x.coeffs)),
#     231         FQ12.zero(),
#     232     )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/optimized_bls12_381/optimized_pairing.py:225, in <listcomp>(.0)
#     221         return FQ12.one()
#     222     return miller_loop(Q, P, final_exponentiate=final_exponentiate)
# --> 225 exptable = [FQ12([0] * i + [1] + [0] * (11 - i)) ** field_modulus for i in range(12)]
#     228 def exp_by_p(x: FQ12) -> FQ12:
#     229     return sum(
#     230         (table_entry * coeff for table_entry, coeff in zip(exptable, x.coeffs)),
#     231         FQ12.zero(),
#     232     )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/fields/optimized_field_elements.py:316, in FQP.__pow__(self, other)
#     314 while other > 0:
#     315     if other & 1:
# --> 316         o = o * t
#     317     other >>= 1
#     318     t = t * t
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/py_ecc/fields/optimized_field_elements.py:276, in FQP.__mul__(self, other)
#     274 for i, eli in enumerate(self.coeffs):
#     275     for j, elj in inner_enumerate:
# --> 276         b[i + j] += int(eli * elj)
#     277 # MID = len(self.coeffs) // 2
#     278 for exp in range(self.degree - 2, -1, -1):
#
# KeyboardInterrupt:

# %%
start_date = datetime.datetime(2024, 9, 1)
end_date = datetime.datetime(2025, 3, 1)
config_generator = ZLEMAConfigGenerator(start_date=start_date, end_date=end_date)

# %%
study_name = "zlem_kalman_1"  # Use a single study name

# Create or load study
study = optuna.create_study(
    study_name=study_name,
    storage=storage,
    direction="maximize",
    load_if_exists=True
)

# Create optimizer with the same storage
optimizer = StrategyOptimizer(
    root_path=root_path,
    storage_name="postgresql://backtest_user:backtest_password@localhost:5433/backtest_db",
    load_cached_data=False,
    resolution="1m"
)
# Out:
# [I 2025-04-20 21:33:04,476] Using an existing study with name 'zlem_kalman_1' instead of creating a new one.

# %%
# Print study information to verify connection
print(f"Study name: {study.study_name}")
print(f"Number of trials: {len(study.trials)}")
try:
    best_trial = study.best_trial
    print(f"Best trial value: {best_trial.value}")
    print("Best trial parameters:")
    for param_name, param_value in best_trial.params.items():
        print(f"  {param_name}: {param_value}")
except ValueError as e:
    print("No completed trials yet")
# Out:
# Study name: zlem_kalman_1
# Number of trials: 641
# Best trial value: -1.2210211630915324
# Best trial parameters:
#   period_fast: 24
#   period_medium: 35
#   period_slow: 76
#   stop_loss: 0.05
#   trailing_stop_activation_price: 0.016
#   trailing_stop_trailing_delta: 0.0016
#   kalman_value1_coef: 0.21000000000000002
#   kalman_value2_coef: 0.14
#   kalman_default_alpha: 0.07

# %%
import sqlalchemy
from sqlalchemy.pool import QueuePool

engine = sqlalchemy.create_engine(
    "postgresql://backtest_user:backtest_password@localhost:5433/backtest_db",
    poolclass=QueuePool,
    pool_size=5,
    max_overflow=10,
    pool_timeout=30,
    pool_pre_ping=True
)

# %%
# Define the root path where the 'data/candles' cache directory resides
cache_root_path = "/Users/derekburns/quants-lab/research_notebooks/getcandles"

# Create optimizer with the same storage configuration, using cached data
optimizer = StrategyOptimizer(
    root_path=cache_root_path, # Use the specific path to the cache parent
    storage_name=storage_url,  # Use the same storage_url from cell 2
    load_cached_data=True,   # Load data from cache
    resolution="1m"
)

# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()
# Out:
# Attempting to load cache from directory: /Users/derekburns/quants-lab/research_notebooks/getcandles/data/candles
# Found files in cache directory: ['binance_perpetual|WLD-USDT|1m.parquet', 'binance|WLD-USDT|1m.parquet', 'binance_perpetual|XRP-USDT|1m.parquet']
# Processing cache file: binance_perpetual|WLD-USDT|1m.parquet
#   Parsed components: connector=binance_perpetual, pair=WLD-USDT, interval=1m
#   Successfully read Parquet file. Shape: (525600, 10)
#   Index is DatetimeIndex.
#   Warning: Both DatetimeIndex and 'timestamp' column exist. Dropping column, using index.
#   Index was already named 'timestamp', column retained after reset.
#   Converting 'timestamp' column from datetime back to numeric seconds.
#   Timestamp column is tz-naive. Localizing to UTC.
#   Successfully loaded cache for key: binance_perpetual_WLD-USDT_1m
#   Cache data range: 2024-04-13 04:18:00 to 2025-04-13 04:17:00
# Processing cache file: binance|WLD-USDT|1m.parquet
#   Parsed components: connector=binance, pair=WLD-USDT, interval=1m
#   Successfully read Parquet file. Shape: (525600, 10)
#   Index is DatetimeIndex.
#   Warning: Both DatetimeIndex and 'timestamp' column exist. Dropping column, using index.
#   Index was already named 'timestamp', column retained after reset.
#   Converting 'timestamp' column from datetime back to numeric seconds.
#   Timestamp column is tz-naive. Localizing to UTC.
#   Successfully loaded cache for key: binance_WLD-USDT_1m
#   Cache data range: 2024-04-12 07:10:00 to 2025-04-12 07:09:00
# Processing cache file: binance_perpetual|XRP-USDT|1m.parquet
#   Parsed components: connector=binance_perpetual, pair=XRP-USDT, interval=1m
#   Successfully read Parquet file. Shape: (525599, 10)
#   Index is DatetimeIndex.
#   Warning: Both DatetimeIndex and 'timestamp' column exist. Dropping column, using index.
#   Index was already named 'timestamp', column retained after reset.
#   Converting 'timestamp' column from datetime back to numeric seconds.
#   Timestamp column is tz-naive. Localizing to UTC.
#   Successfully loaded cache for key: binance_perpetual_XRP-USDT_1m
#   Cache data range: 2024-04-14 00:53:00 to 2025-04-14 00:51:00
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745200835.108668 4318186 fork_posix.cc:75] Other threads are currently calling into gRPC, skipping fork() handlers
# python(7678) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Optuna dashboard launched successfully. Access it at http://localhost:8080

# %%
try:
    await optimizer.optimize(
        study_name=study_name,
        config_generator=config_generator,
        n_trials=10000
    )
finally:
    # Clean up resources
    if hasattr(optimizer, '_backtesting_engine'):
        optimizer._backtesting_engine.cleanup()
# Out:
# [I 2025-04-20 22:00:39,926] Using an existing study with name 'zlem_kalman_1' instead of creating a new one.
# 2025-04-20 22:01:10,432 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17cb782b0>
# 2025-04-20 22:34:28,531 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x33efd6290>
# 2025-04-20 22:34:28,785 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x1766c0340>, 174762.342196625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x33efd5990>
