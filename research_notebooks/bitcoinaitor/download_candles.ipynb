# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.data_sources.clob import CLOBDataSource

# Get trading rules and candles
clob = CLOBDataSource()

# %%
# Constants
CONNECTOR_NAME = "binance"
INTERVAL = "1s"
TRADING_PAIR = "WLD-USDT"
DAYS = 3

# %% [markdown]
# # Download data
# - Get trading rules
# - Get candles for the last x days

# %%
await clob.get_candles_last_days(CONNECTOR_NAME, TRADING_PAIR, INTERVAL, DAYS)

clob.dump_candles_cache(root_path)
# Out:
# 2025-03-02 13:53:01,760 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x179e23f10>
# 2025-03-02 13:53:01,763 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17245c2e0>, 414225.583364041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x179e3c310>

# %%
from core.data_structures.candles import Candles

candles: Candles = all_candles["1m"][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from core.data_structures.candles import Candles
# ----> 3 candles: Candles = all_candles["1m"][0]
#
# NameError: name 'all_candles' is not defined
