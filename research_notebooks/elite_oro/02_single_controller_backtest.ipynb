# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.backtesting import BacktestingEngine

backtesting = BacktestingEngine(root_path=root_path, load_cached_data=False)

# %%
from hummingbot.strategy_v2.executors.position_executor.data_types import TrailingStop
from controllers.directional_trading.elite_oro_1 import EliteOroConfig
import datetime
from decimal import Decimal


# Controller configuration
connector_name = "binance_perpetual"
trading_pair = "WLD-USDT"
interval = "1m"
total_amount_quote = 1000
max_executors_per_side = 2
take_profit = 0.31
stop_loss = 0.065
trailing_stop_activation_price = 0.029
trailing_stop_trailing_delta = 0.017
time_limit = 60 * 60 * 2  # 2 hours
cooldown_time = 60  # 1 minute

# Elite Oro specific parameters
zlema_fast = 7  # Range: 3-8
zlema_medium = 17  # Range: 8-21
zlema_slow = 19  # Range: 13-34
atr_length = 17  # Range: 10-21
atr_multiplier = 1.2000000000000002  # Range: 0.8-1.5
volume_ma_period = 25
volume_surge = 2.7  # Range: 1.5-3.0
price_channel_period = 11
rsi_period = 8

# Creating the instance of the configuration and the controller
config = EliteOroConfig(
    id=f"elite_oro_{connector_name}_{interval}_{trading_pair}",
    connector_name=connector_name,
    trading_pair=trading_pair,
    interval=interval,
    zlema_fast=zlema_fast,
    zlema_medium=zlema_medium,
    zlema_slow=zlema_slow,
    atr_length=atr_length,
    atr_multiplier=Decimal(atr_multiplier),
    volume_ma_period=volume_ma_period,
    volume_surge=Decimal(volume_surge),
    price_channel_period=price_channel_period,
    rsi_period=rsi_period,
    total_amount_quote=Decimal(total_amount_quote),
    take_profit=Decimal(take_profit),
    stop_loss=Decimal(stop_loss),
    trailing_stop=TrailingStop(
        activation_price=Decimal(trailing_stop_activation_price),
        trailing_delta=Decimal(trailing_stop_trailing_delta)
    ),
    time_limit=time_limit,
    max_executors_per_side=max_executors_per_side,
    cooldown_time=cooldown_time,
)

# %%
# Running the backtesting this will output a backtesting result object that has built in methods to visualize the results

start = int(datetime.datetime(2025, 1, 1).timestamp())
end = int(datetime.datetime(2025, 3, 1).timestamp())


backtesting_result = await backtesting.run_backtesting(config, start, end, "1m")
# Out:
# 2025-03-03 10:32:27,789 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14123bd30>
# 2025-03-03 10:32:27,791 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14111eb60>, 488592.952210916)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14123bd60>
# 2025-03-03 10:32:42,838 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x141483a90>
# 2025-03-03 10:32:42,848 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x141462fe0>, 488607.996328333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x141483ac0>
# 2025-03-03 10:32:58,623 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x141483b50>
# 2025-03-03 10:32:58,626 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x141463dc0>, 488623.782487)])']
# connector: <aiohttp.connector.TCPConnector object at 0x141483f40>

# %%
# Let's see what is inside the backtesting results
print(backtesting_result.get_results_summary())
backtesting_result.get_backtesting_figure()
# Out:
# Net PNL: $90.48 (9.05%) | Max Drawdown: $-104.22 (-10.34%)
# Total Volume ($): 104000.00 | Sharpe Ratio: 2.39 | Profit Factor: 1.27
# Total Executors: 104 | Accuracy Long: 0.54 | Accuracy Short: 0.55
# Close Types: Take Profit: 0 | Stop Loss: 2 | Time Limit: 95 |
#              Trailing Stop: 7 | Early Stop: 0

# %%
# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
import pandas as pd

executors_df = backtesting_result.executors_df
executors_df.head()
# Out:
#                                              id  timestamp               type  \
# 0  9x48pbCfX3hG1DwgYhsPiKgDLxX5q9RieSmosdShQw7b 1735825920  position_executor
# 1  Ddg2Meww2sCrGVeuXQxaMPXmPvjbYYNizedqa5NacdTG 1735920900  position_executor
# 2  EBneKaLrbxAiqib6361bXwBNPzxD6p3TciorrqXEX8Q1 1735990740  position_executor
# 3  ADsBHRZk7TcAgSys4zaxfFqsmEUyoz3WoeaoBXPBDfQw 1736012880  position_executor
# 4  ATt9FvkYJmmfghVLhFCaayNKn46WF77jz4grcYCHpfRJ 1736019480  position_executor
#
#    close_timestamp            close_type                     status  \
# 0       1735833120  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 1       1735928100  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 2       1735997940  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 3       1736020080  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 4       1736026680  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
#
#                                               config  \
# 0  {'id': '9x48pbCfX3hG1DwgYhsPiKgDLxX5q9RieSmosd...
# 1  {'id': 'Ddg2Meww2sCrGVeuXQxaMPXmPvjbYYNizedqa5...
# 2  {'id': 'EBneKaLrbxAiqib6361bXwBNPzxD6p3Tciorrq...
# 3  {'id': 'ADsBHRZk7TcAgSys4zaxfFqsmEUyoz3WoeaoBX...
# 4  {'id': 'ATt9FvkYJmmfghVLhFCaayNKn46WF77jz4grcY...
#
#                                          net_pnl_pct  \
# 0  0.01493104044992437165473297966400423320010304...
# 1  0.00207022696929253305353491043661051662638783...
# 2  0.01283634531407333925767666471529082627967000...
# 3  0.00020260212056071372471038882778771039738785...
# 4  -0.0049745267939752084440652168950691702775657...
#
#                                        net_pnl_quote  \
# 0  7.46552022496218548042179463664069771766662597...
# 1  1.03511348464626662391196987300645560026168823...
# 2  6.41817265703666972598284701234661042690277099...
# 3  0.10130106028035686105415180691124987788498401...
# 4  -2.4872633969876041248880937928333878517150878...
#
#                                       cum_fees_quote  \
# 0  0.29999999999999998889776975374843459576368331...
# 1  0.29999999999999998889776975374843459576368331...
# 2  0.29999999999999998889776975374843459576368331...
# 3  0.29999999999999998889776975374843459576368331...
# 4  0.29999999999999993338661852249060757458209991...
#
#                                filled_amount_quote  is_active  is_trading  \
# 0                                             1000      False       False
# 1                                             1000      False       False
# 2                                             1000      False       False
# 3                                             1000      False       False
# 4  999.9999999999998863131622783839702606201171875      False       False
#
#                                          custom_info controller_id  side
# 0  {'close_price': 2.2756, 'level_id': None, 'sid...          None  SELL
# 1  {'close_price': 2.3904, 'level_id': None, 'sid...          None  SELL
# 2  {'close_price': 2.4136, 'level_id': None, 'sid...          None   BUY
# 3  {'close_price': 2.3692, 'level_id': None, 'sid...          None   BUY
# 4  {'close_price': 2.3878, 'level_id': None, 'sid...          None  SELL

# %% [markdown]
# ### Backtesting Analysis

# %% [markdown]
# ### Scatter of PNL per Trade
# This bar chart illustrates the PNL for each individual trade. Positive PNLs are shown in green and negative PNLs in red, providing a clear view of profitable vs. unprofitable trades.

# %%
import plotly.express as px

# Create a new column for profitability
executors_df['profitable'] = executors_df['net_pnl_quote'] > 0

# Create the scatter plot
fig = px.scatter(
    executors_df,
    x="timestamp",
    y='net_pnl_quote',
    title='PNL per Trade',
    color='profitable',
    color_discrete_map={True: 'green', False: 'red'},
    labels={'timestamp': 'Timestamp', 'net_pnl_quote': 'Net PNL (Quote)'},
    hover_data=['filled_amount_quote', 'side']
)

# Customize the layout
fig.update_layout(
    xaxis_title="Timestamp",
    yaxis_title="Net PNL (Quote)",
    legend_title="Profitable",
    font=dict(size=12, color="white"),
    showlegend=False,
    plot_bgcolor='rgba(0,0,0,0.8)',  # Dark background
    paper_bgcolor='rgba(0,0,0,0.8)',  # Dark background for the entire plot area
    xaxis=dict(gridcolor="gray"),
    yaxis=dict(gridcolor="gray")
)

# Add a horizontal line at y=0 to clearly separate profits and losses
fig.add_hline(y=0, line_dash="dash", line_color="lightgray")

# Show the plot
fig.show()

# %% [markdown]
# ### Histogram of PNL Distribution
# The histogram displays the distribution of PNL values across all trades. It helps in understanding the frequency and range of profit and loss outcomes.

# %%
fig = px.histogram(executors_df, x='net_pnl_quote', title='PNL Distribution')
fig.show()

# %% [markdown]
# # Conclusion
# We can see that the indicator has potential to bring good signals to trade and might be interesting to see how we can design a market maker that shifts the mid price based on this indicator.
# A lot of the short signals are wrong but if we zoom in into the loss signals we can see that the losses are not that big and the wins are bigger and if we had implemented the trailing stop feature probably a lot of them are going to be profits.

# %% [markdown]
# # Next steps
# - Filter only the loss signals and understand what you can do to prevent them
# - Try different configuration values for the indicator
# - Test in multiple markets, pick mature markets like BTC-USDT or ETH-USDT and also volatile markets like DOGE-USDT or SHIB-USDT
