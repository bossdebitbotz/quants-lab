# %%
# This is necessary to recognize the modules
import os
import sys
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.services.timescale_client import TimescaleClient

# Create test connection to the new backtesting database
ts_client = TimescaleClient(
    host="localhost",
    port=5433,  # Using the new port we specified
    user="backtest_user",
    password="backtest_password",
    database="backtest_db"
)

# Test connection
await ts_client.connect()

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer

# %%
from research_notebooks.ichismugplug.ichismugplug_config_gen_simple import IchimokuSmugPlugConfigGenerator

# Define the date range for the optimization
start_date = datetime.datetime(2025, 1, 31)
end_date = datetime.datetime(2025, 2, 10)

# Create the configuration generator
config_generator = IchimokuSmugPlugConfigGenerator(start_date=start_date, end_date=end_date)

# %%
if 'optimizer' in globals():
    await optimizer.close()

# Clean up any stale connections without deleting data
import sqlite3

def unlock_database():
    try:
        # Force close any existing connections
        conn = sqlite3.connect('optuna.db')
        conn.execute("PRAGMA busy_timeout = 5000")
        conn.execute("PRAGMA journal_mode = DELETE")
        conn.close()
        print("Database unlocked successfully")
    except Exception as e:
        print(f"Error during unlock: {str(e)}")

unlock_database()
# Out:
# Database unlocked successfully

# %%
# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

import optuna
from optuna.storages import RDBStorage

# Define TimescaleDB configuration
timescale_config = {
    "host": "localhost",
    "port": 5433,
    "user": "backtest_user",
    "password": "backtest_password",
    "database": "backtest_db"
}

# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

# Create the optimizer with correct parameters
optimizer = StrategyOptimizer(
    root_path=root_path,
    storage_name="sqlite:///optuna.db",  # Using SQLite for now
    load_cached_data=False,
    resolution="1m"
)

# %%
# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"zen_optimization",
    config_generator=config_generator,
    n_trials=10000,
)
optimizer.get_study_best_params(f"zen_optimization")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1739415882.544821  131822 fork_posix.cc:75] Other threads are currently calling into gRPC, skipping fork() handlers
# [I 2025-02-12 22:04:42,699] A new study created in RDB with name: zen_optimization
# 2025-02-12 22:04:43,706 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17d7b7a30>
# 2025-02-12 22:04:43,707 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x16d010280>, 7545.345324375)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17d7b7400>
# Listening on http://127.0.0.1:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [12/Feb/2025 22:04:47] "GET /api/studies/10?after=48 HTTP/1.1" 200 121959
# 2025-02-12 22:04:47,868 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e0a4a60>
# 2025-02-12 22:04:47,870 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773400>, 7549.503546666)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e0a4a90>
# 2025-02-12 22:04:51,071 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e0a4a00>
# 2025-02-12 22:04:51,072 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d772f80>, 7552.707864708)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e0a48b0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 167, in update_processed_data
#     isb = df["ISB_26"]  # Base line (Kijun-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISB_26'
# An error occurred during optimization: 'ISB_26'
# 127.0.0.1 - - [12/Feb/2025 22:04:52] "GET /api/studies HTTP/1.1" 200 249
# 2025-02-12 22:04:54,207 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e34ff40>
# 2025-02-12 22:04:54,208 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x16d010280>, 7555.844056041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e348ee0>
# 127.0.0.1 - - [12/Feb/2025 22:04:54] "GET /api/meta HTTP/1.1" 200 60
# 127.0.0.1 - - [12/Feb/2025 22:04:54] "GET /api/studies/11/param_importances HTTP/1.1" 200 26
# 127.0.0.1 - - [12/Feb/2025 22:04:54] "GET /api/studies/11?after=0 HTTP/1.1" 200 16427
# 127.0.0.1 - - [12/Feb/2025 22:04:54] "GET /api/studies/11/param_importances HTTP/1.1" 200 26
# 2025-02-12 22:04:57,425 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e0a60e0>
# 2025-02-12 22:04:57,427 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fe80>, 7559.0627565)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e0a4970>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 2025-02-12 22:05:00,474 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e34a860>
# 2025-02-12 22:05:00,475 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f4a60>, 7562.111099416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e34a140>
# 2025-02-12 22:05:03,701 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e34ba60>
# 2025-02-12 22:05:03,703 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17bd900a0>, 7565.338584333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e34a5f0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:05:04] "GET /api/studies/11?after=1 HTTP/1.1" 200 20924
# /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna_dashboard/_importance.py:75: ExperimentalWarning: PedAnovaImportanceEvaluator is experimental (supported from v3.6.0). The interface can change in the future.
#   return get_param_importances(study, target=target, evaluator=PedAnovaImportanceEvaluator())
# 127.0.0.1 - - [12/Feb/2025 22:05:04] "GET /api/studies/11/param_importances HTTP/1.1" 200 1431
# 2025-02-12 22:05:06,774 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e3f5cc0>
# 2025-02-12 22:05:06,775 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37ffa0>, 7568.411403)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e3f5c30>
# 2025-02-12 22:05:09,984 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e318e80>
# 2025-02-12 22:05:09,985 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37ffa0>, 7571.622452)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e318fa0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 2025-02-12 22:05:13,074 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e3719f0>
# 2025-02-12 22:05:13,076 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f7f40>, 7574.712923333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e373370>
# 127.0.0.1 - - [12/Feb/2025 22:05:14] "GET /api/studies/11?after=3 HTTP/1.1" 200 16966
# 127.0.0.1 - - [12/Feb/2025 22:05:14] "GET /api/studies/11/param_importances HTTP/1.1" 200 1431
# 2025-02-12 22:05:16,283 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e372d10>
# 2025-02-12 22:05:16,285 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fca0>, 7577.920377541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e372440>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 167, in update_processed_data
#     isb = df["ISB_26"]  # Base line (Kijun-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISB_26'
# An error occurred during optimization: 'ISB_26'
# 2025-02-12 22:05:19,363 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e263490>
# 2025-02-12 22:05:19,365 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5840>, 7581.00026925)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e262da0>
# 2025-02-12 22:05:22,600 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e2628f0>
# 2025-02-12 22:05:22,601 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d73fac0>, 7584.238750583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e2638b0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:05:25] "GET /api/studies/11?after=4 HTTP/1.1" 200 21178
# 127.0.0.1 - - [12/Feb/2025 22:05:25] "GET /api/studies/11/param_importances HTTP/1.1" 200 1431
# 2025-02-12 22:05:25,678 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e263550>
# 2025-02-12 22:05:25,680 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d73fac0>, 7587.316742666)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e263490>
# 2025-02-12 22:05:28,903 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e372c50>
# 2025-02-12 22:05:28,905 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d4b8100>, 7590.541046291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e372bc0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 167, in update_processed_data
#     isb = df["ISB_26"]  # Base line (Kijun-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISB_26'
# An error occurred during optimization: 'ISB_26'
# 2025-02-12 22:05:32,105 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e263430>
# 2025-02-12 22:05:32,106 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fd60>, 7593.743080541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e263370>
# 127.0.0.1 - - [12/Feb/2025 22:05:35] "GET /api/studies/11?after=6 HTTP/1.1" 200 17200
# 127.0.0.1 - - [12/Feb/2025 22:05:35] "GET /api/studies/11/param_importances HTTP/1.1" 200 1431
# 2025-02-12 22:05:35,303 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e34dc60>
# 2025-02-12 22:05:35,303 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x16d010280>, 7596.943070791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e34de40>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 2025-02-12 22:05:38,432 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e262bf0>
# 2025-02-12 22:05:38,434 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fe80>, 7600.070774666)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e263970>
# 2025-02-12 22:05:41,668 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e262290>
# 2025-02-12 22:05:41,670 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37ff40>, 7603.3082435)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e263fd0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:05:42] "GET /api/studies/11?after=7 HTTP/1.1" 200 21212
# 127.0.0.1 - - [12/Feb/2025 22:05:44] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 2025-02-12 22:05:44,753 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e319600>
# 2025-02-12 22:05:44,755 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d770700>, 7606.391606791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e318220>
# 127.0.0.1 - - [12/Feb/2025 22:05:46] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 2025-02-12 22:05:48,118 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e373490>
# 2025-02-12 22:05:48,119 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773b20>, 7609.756748083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e3717b0>
# 127.0.0.1 - - [12/Feb/2025 22:05:48] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 127.0.0.1 - - [12/Feb/2025 22:05:50] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 127.0.0.1 - - [12/Feb/2025 22:05:52] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 127.0.0.1 - - [12/Feb/2025 22:05:54] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 127.0.0.1 - - [12/Feb/2025 22:05:56] "GET /api/studies/11?after=9 HTTP/1.1" 200 13150
# 127.0.0.1 - - [12/Feb/2025 22:05:58] "GET /api/studies/11?after=9 HTTP/1.1" 200 452758
# 2025-02-12 22:06:00,984 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e3713c0>
# 2025-02-12 22:06:00,986 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e100b80>, 7622.623359458)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e372800>
# 127.0.0.1 - - [12/Feb/2025 22:06:01] "GET /api/studies/11?after=10 HTTP/1.1" 200 231472
# 2025-02-12 22:06:04,165 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e31be50>
# 2025-02-12 22:06:04,167 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102320>, 7625.804734208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e31a1a0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:04] "GET /api/studies/11?after=10 HTTP/1.1" 200 235614
# 2025-02-12 22:06:07,341 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e847490>
# 2025-02-12 22:06:07,343 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102980>, 7628.981063958)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e847d90>
# 127.0.0.1 - - [12/Feb/2025 22:06:07] "GET /api/studies/11?after=11 HTTP/1.1" 200 231597
# 127.0.0.1 - - [12/Feb/2025 22:06:10] "GET /api/studies/11?after=11 HTTP/1.1" 200 231597
# 2025-02-12 22:06:10,516 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e845b70>
# 2025-02-12 22:06:10,517 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102980>, 7632.156754083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e844ca0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:13] "GET /api/studies/11?after=11 HTTP/1.1" 200 235643
# 2025-02-12 22:06:13,898 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e7ef550>
# 2025-02-12 22:06:13,899 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773760>, 7635.537938791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7eee30>
# 127.0.0.1 - - [12/Feb/2025 22:06:16] "GET /api/studies/11?after=12 HTTP/1.1" 200 231602
# 2025-02-12 22:06:17,086 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e7ed660>
# 2025-02-12 22:06:17,086 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102980>, 7638.72746575)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7ede70>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:19] "GET /api/studies/11?after=12 HTTP/1.1" 200 235781
# 2025-02-12 22:06:20,267 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e5f6620>
# 2025-02-12 22:06:20,268 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e101ea0>, 7641.90670525)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e5f5480>
# 127.0.0.1 - - [12/Feb/2025 22:06:22] "GET /api/studies/11?after=13 HTTP/1.1" 200 231735
# 2025-02-12 22:06:23,628 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e5a3b20>
# 2025-02-12 22:06:23,629 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773280>, 7645.270677583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7ece50>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:25] "GET /api/studies/11?after=13 HTTP/1.1" 200 235984
# 2025-02-12 22:06:26,721 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e5a36d0>
# 2025-02-12 22:06:26,722 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fb20>, 7648.361398208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e5a1810>
# 127.0.0.1 - - [12/Feb/2025 22:06:28] "GET /api/studies/11?after=14 HTTP/1.1" 200 231907
# 2025-02-12 22:06:29,959 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e5a1bd0>
# 2025-02-12 22:06:29,961 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fbe0>, 7651.598176875)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e5a25f0>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 167, in update_processed_data
#     isb = df["ISB_26"]  # Base line (Kijun-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISB_26'
# An error occurred during optimization: 'ISB_26'
# 127.0.0.1 - - [12/Feb/2025 22:06:31] "GET /api/studies/11?after=14 HTTP/1.1" 200 236088
# 2025-02-12 22:06:33,227 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e846980>
# 2025-02-12 22:06:33,228 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e2b05e0>, 7654.868416541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e8454b0>
# 127.0.0.1 - - [12/Feb/2025 22:06:34] "GET /api/studies/11?after=15 HTTP/1.1" 200 232044
# 127.0.0.1 - - [12/Feb/2025 22:06:36] "GET /api/studies/11?after=15 HTTP/1.1" 200 232044
# 2025-02-12 22:06:36,473 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e7edd50>
# 2025-02-12 22:06:36,474 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e37fbe0>, 7658.115668375)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7ee170>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:38] "GET /api/studies/11?after=15 HTTP/1.1" 200 236056
# 2025-02-12 22:06:39,629 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e5f6650>
# 2025-02-12 22:06:39,630 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773280>, 7661.270465333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e5f71f0>
# 127.0.0.1 - - [12/Feb/2025 22:06:40] "GET /api/studies/11?after=16 HTTP/1.1" 200 231979
# 127.0.0.1 - - [12/Feb/2025 22:06:42] "GET /api/studies/11?after=16 HTTP/1.1" 200 231979
# 2025-02-12 22:06:42,876 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e31be50>
# 2025-02-12 22:06:42,877 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773040>, 7664.518211458)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e31ae30>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 127.0.0.1 - - [12/Feb/2025 22:06:43] "GET /api/studies/11/param_importances HTTP/1.1" 200 1431
# 2025-02-12 22:06:46,056 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e7c5720>
# 2025-02-12 22:06:46,057 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773040>, 7667.697453625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7c79d0>
# 2025-02-12 22:06:49,296 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x17e7c7850>
# 2025-02-12 22:06:49,298 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773040>, 7670.9376635)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17e7c5090>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
# ...
# connector: <aiohttp.connector.TCPConnector object at 0x30ad720e0>
# 2025-02-13 10:35:05,321 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a85c580>
# 2025-02-13 10:35:05,323 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f79a0>, 52567.869585208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30b281c90>
# 2025-02-13 10:35:08,551 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30adaa530>
# 2025-02-13 10:35:08,552 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f79a0>, 52571.098424583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30adabd00>
# 2025-02-13 10:35:17,999 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a451ae0>
# 2025-02-13 10:35:18,002 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f79a0>, 52580.546889375)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30aeb2740>
# 2025-02-13 10:35:21,247 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30afd41f0>
# 2025-02-13 10:35:21,252 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f7fa0>, 52583.792386625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30afd5fc0>
# 127.0.0.1 - - [13/Feb/2025 10:35:30] "GET /api/studies/11?after=4130 HTTP/1.1" 200 396161
# 2025-02-13 10:35:32,862 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30b22dab0>
# 2025-02-13 10:35:32,864 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f7fa0>, 52595.410179541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30b22f3a0>
# 2025-02-13 10:35:37,702 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a80a440>
# 2025-02-13 10:35:37,704 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d772da0>, 52600.248187583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ac6bf10>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISB_26'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 167, in update_processed_data
#     isb = df["ISB_26"]  # Base line (Kijun-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISB_26'
# An error occurred during optimization: 'ISB_26'
# 127.0.0.1 - - [13/Feb/2025 10:35:38] "GET /api/studies/11/param_importances HTTP/1.1" 200 1440
# 2025-02-13 10:35:43,086 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30aea9300>
# 2025-02-13 10:35:43,089 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e100340>, 52605.624287333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30aeab640>
# 2025-02-13 10:35:46,226 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30aa2d120>
# 2025-02-13 10:35:46,227 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e100340>, 52608.775301791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a749fc0>
# 2025-02-13 10:35:55,116 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a477fa0>
# 2025-02-13 10:35:55,117 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e100340>, 52617.665122583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a475600>
# 2025-02-13 10:35:58,268 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ae2bee0>
# 2025-02-13 10:35:58,269 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e1019c0>, 52620.81681875)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ae2b490>
# 2025-02-13 10:36:08,726 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ade7160>
# 2025-02-13 10:36:08,728 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e1019c0>, 52631.274955583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ade5330>
# 2025-02-13 10:36:11,916 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3080edc90>
# 2025-02-13 10:36:11,917 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e1019c0>, 52634.465172083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ae2b310>
# 2025-02-13 10:36:19,654 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30aed3c10>
# 2025-02-13 10:36:19,656 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e100e80>, 52642.203042916)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30aed0610>
# 2025-02-13 10:36:24,305 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ac8cc10>
# 2025-02-13 10:36:24,311 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102560>, 52646.854374208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ac8c340>
# 2025-02-13 10:36:31,977 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ae57f40>
# 2025-02-13 10:36:31,978 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e102560>, 52654.526345625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ae556f0>
# 2025-02-13 10:36:36,748 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30af80400>
# 2025-02-13 10:36:36,751 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773040>, 52659.297934083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30afddae0>
# 2025-02-13 10:36:58,214 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30af84430>
# 2025-02-13 10:36:58,219 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d773040>, 52680.753854833)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30af84790>
# 127.0.0.1 - - [13/Feb/2025 10:37:00] "GET /api/studies/11?after=4134 HTTP/1.1" 200 661605
# 2025-02-13 10:37:01,532 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30af512a0>
# 2025-02-13 10:37:01,536 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e2b1ba0>, 52684.06706725)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3080edc90>
# 127.0.0.1 - - [13/Feb/2025 10:37:08] "GET /api/studies/11/param_importances HTTP/1.1" 200 1443
# 2025-02-13 10:37:17,830 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30afd53f0>
# 2025-02-13 10:37:17,832 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e756860>, 52700.379805208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30afd7760>
# 2025-02-13 10:37:21,676 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ad45d50>
# 2025-02-13 10:37:21,678 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d772da0>, 52704.226079541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30afd7850>
# 2025-02-13 10:37:29,245 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30aed2650>
# 2025-02-13 10:37:29,246 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d772da0>, 52711.796667583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30aed02b0>
# 2025-02-13 10:37:32,400 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ade4d60>
# 2025-02-13 10:37:32,401 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e5bb2e0>, 52714.950471791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ade7340>
# 2025-02-13 10:37:39,784 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30af8ad70>
# 2025-02-13 10:37:39,785 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e5bace0>, 52722.335396041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30af8b220>
# 2025-02-13 10:37:43,959 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ade7fa0>
# 2025-02-13 10:37:43,962 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e5b97e0>, 52726.509688208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30ade7790>
# 2025-02-13 10:37:51,841 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a4841f0>
# 2025-02-13 10:37:51,854 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17e5bb100>, 52734.389500791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a35de40>
# 2025-02-13 10:37:55,233 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30b229480>
# 2025-02-13 10:37:55,235 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52737.78365275)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30b228af0>
# 2025-02-13 10:38:03,699 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a475060>
# 2025-02-13 10:38:03,704 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52746.2464635)])']
# connector: <aiohttp.connector.TCPConnector object at 0x17fac48b0>
# 2025-02-13 10:38:07,727 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ae54b50>
# 2025-02-13 10:38:07,729 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52750.27881025)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a74b460>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas/_libs/hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'ISA_9'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/derekburns/quants-lab/core/backtesting/optimizer.py", line 341, in _async_objective
#     backtesting_result = await self._backtesting_engine.run_backtesting(
#   File "/Users/derekburns/quants-lab/core/backtesting/engine.py", line 75, in run_backtesting
#     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py", line 93, in run_backtesting
#     await self.controller.update_processed_data()
#   File "/Users/derekburns/quants-lab/controllers/directional_trading/ichismugplug.py", line 166, in update_processed_data
#     isa = df["ISA_9"]  # Conversion line (Tenkan-sen)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#   File "/opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'ISA_9'
# An error occurred during optimization: 'ISA_9'
# 2025-02-13 10:38:11,770 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30aeaa0e0>
# 2025-02-13 10:38:11,772 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52754.321261541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30aea8850>
# 2025-02-13 10:38:14,963 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30b229d20>
# 2025-02-13 10:38:14,965 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52757.514177)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30b229fc0>
# 2025-02-13 10:38:22,723 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30ae0fe80>
# 2025-02-13 10:38:22,726 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x17d7f5960>, 52765.27497025)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a42fe50>
# 2025-02-13 10:38:26,162 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30b22c2e0>
# 2025-02-13 10:38:26,165 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x11765a0e0>, 52768.713707791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30af89b70>

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer
from research_notebooks.elitesmugplug.elitesmugplug_config_gen_simple import SmugPlug3LiteConfigGenerator

# Define the date range for the optimization
start_date = datetime.datetime(2025, 1, 31)
end_date = datetime.datetime(2025, 2, 10)

# Database configuration for Docker container
timescale_config = {
    "host": "localhost",  # or your Docker host IP
    "port": 5432,        # exposed port from docker-compose
    "user": "admin",     # from docker-compose
    "password": "admin", # from docker-compose
    "database": "timescaledb"
}

# Create the configuration generator
config_generator = SmugPlug3LiteConfigGenerator(
    start_date=start_date, 
    end_date=end_date,
    timescale_config=timescale_config
)

# Create the optimizer with database connection
optimizer = StrategyOptimizer(
    root_path=root_path,
    db_host=timescale_config["host"],
    db_port=timescale_config["port"],
    db_user=timescale_config["user"],
    db_pass=timescale_config["password"]
)

# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"smugplug_optimization",
    config_generator=config_generator,
    n_trials=100,
)
