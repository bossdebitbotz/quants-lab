# %%
# This is necessary to recognize the modules
import os
import sys
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.services.timescale_client import TimescaleClient

# Create test connection to the new backtesting database
ts_client = TimescaleClient(
    host="localhost",
    port=5433,  # Using the new port we specified
    user="backtest_user",
    password="backtest_password",
    database="backtest_db"
)

# Test connection
await ts_client.connect()

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer

# %%
from research_notebooks.oro.oro_config_gen_simple import OroConfigGenerator

# Define the date range for the optimization
start_date = datetime.datetime(2025, 1, 1)
end_date = datetime.datetime(2025, 2, 22)

# Create the configuration generator
config_generator = OroConfigGenerator(start_date=start_date, end_date=end_date)

# %%
if 'optimizer' in globals():
    await optimizer.close()

# Clean up any stale connections without deleting data
import sqlite3

def unlock_database():
    try:
        # Force close any existing connections
        conn = sqlite3.connect('optuna.db')
        conn.execute("PRAGMA busy_timeout = 5000")
        conn.execute("PRAGMA journal_mode = DELETE")
        conn.close()
        print("Database unlocked successfully")
    except Exception as e:
        print(f"Error during unlock: {str(e)}")

unlock_database()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 2
#       1 if 'optimizer' in globals():
# ----> 2     await optimizer.close()
#       4 # Clean up any stale connections without deleting data
#       5 import sqlite3
#
# AttributeError: 'StrategyOptimizer' object has no attribute 'close'
# 127.0.0.1 - - [27/Feb/2025 16:48:34] "GET /api/studies/5?after=1390 HTTP/1.1" 200 725266
# 127.0.0.1 - - [27/Feb/2025 16:48:40] "GET /api/studies/5/param_importances HTTP/1.1" 200 1254
# 127.0.0.1 - - [27/Feb/2025 16:49:39] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:50:47] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:51:28] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:52:15] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:52:55] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:53:43] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:54:17] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:54:51] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:55:26] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:55:54] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:56:35] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:57:20] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:57:44] "GET /api/studies HTTP/1.1" 200 706
# 127.0.0.1 - - [27/Feb/2025 16:57:46] "GET /api/meta HTTP/1.1" 200 60
# 127.0.0.1 - - [27/Feb/2025 16:57:47] "GET /api/studies/6?after=0 HTTP/1.1" 200 6297
# 127.0.0.1 - - [27/Feb/2025 16:57:47] "GET /api/studies/6/param_importances HTTP/1.1" 200 26
# 127.0.0.1 - - [27/Feb/2025 16:57:48] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:57:48] "GET /api/studies/5?after=1391 HTTP/1.1" 200 356489
# 127.0.0.1 - - [27/Feb/2025 16:57:57] "GET /api/studies/6?after=0 HTTP/1.1" 200 16685
# 127.0.0.1 - - [27/Feb/2025 16:57:57] "GET /api/studies/6/param_importances HTTP/1.1" 200 26
# 127.0.0.1 - - [27/Feb/2025 16:58:07] "GET /api/studies/6?after=1 HTTP/1.1" 200 11901
# 127.0.0.1 - - [27/Feb/2025 16:58:17] "GET /api/studies/6?after=1 HTTP/1.1" 200 11901
# 127.0.0.1 - - [27/Feb/2025 16:58:28] "GET /api/studies/6?after=1 HTTP/1.1" 200 11901
# 127.0.0.1 - - [27/Feb/2025 16:59:07] "GET /api/studies/6?after=1 HTTP/1.1" 200 1189203
# 127.0.0.1 - - [27/Feb/2025 16:59:07] "GET /api/studies/6/param_importances HTTP/1.1" 200 1255
# 127.0.0.1 - - [27/Feb/2025 16:59:18] "GET /api/studies/6?after=2 HTTP/1.1" 200 598164
# 127.0.0.1 - - [27/Feb/2025 16:59:31] "GET /api/studies/6?after=2 HTTP/1.1" 200 598164
# 127.0.0.1 - - [27/Feb/2025 16:59:41] "GET /api/studies/6?after=2 HTTP/1.1" 200 598164
# 127.0.0.1 - - [27/Feb/2025 16:59:54] "GET /api/studies/6?after=2 HTTP/1.1" 200 1567055
# 127.0.0.1 - - [27/Feb/2025 16:59:54] "GET /api/studies/6/param_importances HTTP/1.1" 200 1255
# 127.0.0.1 - - [27/Feb/2025 17:00:08] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:00:23] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:00:35] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:00:48] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:01:02] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:01:13] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:01:26] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:01:38] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:01:49] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:02:03] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:02:13] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:02:26] "GET /api/studies/6?after=3 HTTP/1.1" 200 787061
# 127.0.0.1 - - [27/Feb/2025 17:02:40] "GET /api/studies/6?after=3 HTTP/1.1" 200 1535553
# 127.0.0.1 - - [27/Feb/2025 17:02:40] "GET /api/studies/6/param_importances HTTP/1.1" 200 1262
# 127.0.0.1 - - [27/Feb/2025 17:02:53] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:03:07] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:03:20] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:03:44] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:03:55] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:04:06] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:04:18] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:04:31] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:04:43] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:04:54] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:05:10] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:05:25] "GET /api/studies/6?after=4 HTTP/1.1" 200 787055
# 127.0.0.1 - - [27/Feb/2025 17:06:25] "GET /api/studies/6?after=4 HTTP/1.1" 200 2247920
# 127.0.0.1 - - [27/Feb/2025 17:06:25] "GET /api/studies/6/param_importances HTTP/1.1" 200 1259
# 127.0.0.1 - - [27/Feb/2025 17:06:44] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:06:56] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:07:07] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:07:18] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:07:32] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:07:44] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:07:56] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:08:08] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:08:19] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:08:30] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:08:41] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:08:52] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:09:03] "GET /api/studies/6?after=5 HTTP/1.1" 200 787089
# 127.0.0.1 - - [27/Feb/2025 17:09:14] "GET /api/studies/6?after=5 HTTP/1.1" 200 1723893
# 127.0.0.1 - - [27/Feb/2025 17:09:14] "GET /api/studies/6/param_importances HTTP/1.1" 200 1262
# 127.0.0.1 - - [27/Feb/2025 17:09:25] "GET /api/studies/6?after=6 HTTP/1.1" 200 787057
# 127.0.0.1 - - [27/Feb/2025 17:09:36] "GET /api/studies/6?after=6 HTTP/1.1" 200 787057
# 127.0.0.1 - - [27/Feb/2025 17:09:52] "GET /api/studies/6?after=6 HTTP/1.1" 200 809983
# 127.0.0.1 - - [27/Feb/2025 17:09:52] "GET /api/studies/6/param_importances HTTP/1.1" 200 1259
# 127.0.0.1 - - [27/Feb/2025 17:10:04] "GET /api/studies/6?after=7 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:10:20] "GET /api/studies/6?after=7 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:10:36] "GET /api/studies/6?after=7 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:10:48] "GET /api/studies/6?after=7 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:11:00] "GET /api/studies/6?after=7 HTTP/1.1" 200 1259707
# 127.0.0.1 - - [27/Feb/2025 17:11:00] "GET /api/studies/6/param_importances HTTP/1.1" 200 1260
# 127.0.0.1 - - [27/Feb/2025 17:11:17] "GET /api/studies/6?after=8 HTTP/1.1" 200 408569
# 127.0.0.1 - - [27/Feb/2025 17:11:28] "GET /api/studies/6?after=8 HTTP/1.1" 200 408569
# 127.0.0.1 - - [27/Feb/2025 17:11:41] "GET /api/studies/6?after=8 HTTP/1.1" 200 408569
# 127.0.0.1 - - [27/Feb/2025 17:11:51] "GET /api/studies/6?after=8 HTTP/1.1" 200 408569
# 127.0.0.1 - - [27/Feb/2025 17:12:04] "GET /api/studies/6?after=8 HTTP/1.1" 200 1020330
# 127.0.0.1 - - [27/Feb/2025 17:12:04] "GET /api/studies/6/param_importances HTTP/1.1" 200 1266
# 127.0.0.1 - - [27/Feb/2025 17:12:16] "GET /api/studies/6?after=9 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:12:28] "GET /api/studies/6?after=9 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:12:39] "GET /api/studies/6?after=9 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:12:49] "GET /api/studies/6?after=9 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:13:01] "GET /api/studies/6?after=9 HTTP/1.1" 200 408539
# 127.0.0.1 - - [27/Feb/2025 17:13:13] "GET /api/studies/6?after=9 HTTP/1.1" 200 2015426
# 127.0.0.1 - - [27/Feb/2025 17:13:13] "GET /api/studies/6/param_importances HTTP/1.1" 200 1266
# 127.0.0.1 - - [27/Feb/2025 17:13:28] "GET /api/studies/6?after=10 HTTP/1.1" 200 408506
# 127.0.0.1 - - [27/Feb/2025 17:13:41] "GET /api/studies/6?after=10 HTTP/1.1" 200 413310
# 127.0.0.1 - - [27/Feb/2025 17:13:41] "GET /api/studies/6/param_importances HTTP/1.1" 200 1266
# 127.0.0.1 - - [27/Feb/2025 17:13:55] "GET /api/studies/6?after=11 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:14:06] "GET /api/studies/6?after=11 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:14:18] "GET /api/studies/6?after=11 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:14:33] "GET /api/studies/6?after=11 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:14:44] "GET /api/studies/6?after=11 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:14:55] "GET /api/studies/6?after=11 HTTP/1.1" 200 1358176
# 127.0.0.1 - - [27/Feb/2025 17:14:55] "GET /api/studies/6/param_importances HTTP/1.1" 200 1265
# 127.0.0.1 - - [27/Feb/2025 17:15:06] "GET /api/studies/6?after=12 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:15:17] "GET /api/studies/6?after=12 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:15:39] "GET /api/studies/6?after=12 HTTP/1.1" 200 753979
# 127.0.0.1 - - [27/Feb/2025 17:15:39] "GET /api/studies/6/param_importances HTTP/1.1" 200 1266
# 127.0.0.1 - - [27/Feb/2025 17:15:52] "GET /api/studies/6?after=13 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:16:04] "GET /api/studies/6?after=13 HTTP/1.1" 200 408570
# 127.0.0.1 - - [27/Feb/2025 17:16:18] "GET /api/studies/6?after=13 HTTP/1.1" 200 624324
# 127.0.0.1 - - [27/Feb/2025 17:16:19] "GET /api/studies/6/param_importances HTTP/1.1" 200 1263
# 127.0.0.1 - - [27/Feb/2025 17:16:32] "GET /api/studies/6?after=14 HTTP/1.1" 200 315711
# 127.0.0.1 - - [27/Feb/2025 17:16:44] "GET /api/studies/6?after=14 HTTP/1.1" 200 315711
# 127.0.0.1 - - [27/Feb/2025 17:16:57] "GET /api/studies/6?after=14 HTTP/1.1" 200 315711
# 127.0.0.1 - - [27/Feb/2025 17:17:08] "GET /api/studies/6?after=14 HTTP/1.1" 200 315711
# 127.0.0.1 - - [27/Feb/2025 17:17:21] "GET /api/studies/6?after=14 HTTP/1.1" 200 315711
# 127.0.0.1 - - [27/Feb/2025 17:17:35] "GET /api/studies/6?after=14 HTTP/1.1" 200 1193343
# 127.0.0.1 - - [27/Feb/2025 17:17:35] "GET /api/studies/6/param_importances HTTP/1.1" 200 1260
# 127.0.0.1 - - [27/Feb/2025 17:17:47] "GET /api/studies/6?after=15 HTTP/1.1" 200 315679
# 127.0.0.1 - - [27/Feb/2025 17:18:00] "GET /api/studies/6?after=15 HTTP/1.1" 200 315679
# 127.0.0.1 - - [27/Feb/2025 17:18:11] "GET /api/studies/6?after=15 HTTP/1.1" 200 315679
# 127.0.0.1 - - [27/Feb/2025 17:18:22] "GET /api/studies/6?after=15 HTTP/1.1" 200 731207
# 127.0.0.1 - - [27/Feb/2025 17:18:22] "GET /api/studies/6/param_importances HTTP/1.1" 200 1265
# 127.0.0.1 - - [27/Feb/2025 17:18:33] "GET /api/studies/6?after=16 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:18:48] "GET /api/studies/6?after=16 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:19:00] "GET /api/studies/6?after=16 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:19:11] "GET /api/studies/6?after=16 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:19:25] "GET /api/studies/6?after=16 HTTP/1.1" 200 971764
# 127.0.0.1 - - [27/Feb/2025 17:19:26] "GET /api/studies/6/param_importances HTTP/1.1" 200 1263
# 127.0.0.1 - - [27/Feb/2025 17:19:38] "GET /api/studies/6?after=17 HTTP/1.1" 200 315737
# 127.0.0.1 - - [27/Feb/2025 17:19:48] "GET /api/studies/6?after=17 HTTP/1.1" 200 315737
# 127.0.0.1 - - [27/Feb/2025 17:19:59] "GET /api/studies/6?after=17 HTTP/1.1" 200 315737
# 127.0.0.1 - - [27/Feb/2025 17:20:09] "GET /api/studies/6?after=17 HTTP/1.1" 200 315737
# 127.0.0.1 - - [27/Feb/2025 17:20:19] "GET /api/studies/6?after=17 HTTP/1.1" 200 315737
# 127.0.0.1 - - [27/Feb/2025 17:20:30] "GET /api/studies/6?after=17 HTTP/1.1" 200 1321972
# 127.0.0.1 - - [27/Feb/2025 17:20:30] "GET /api/studies/6/param_importances HTTP/1.1" 200 1266
# 127.0.0.1 - - [27/Feb/2025 17:20:47] "GET /api/studies/6?after=18 HTTP/1.1" 200 315709
# 127.0.0.1 - - [27/Feb/2025 17:21:04] "GET /api/studies/6?after=18 HTTP/1.1" 200 315709
# 127.0.0.1 - - [27/Feb/2025 17:21:23] "GET /api/studies/6?after=18 HTTP/1.1" 200 315709
# 127.0.0.1 - - [27/Feb/2025 17:21:37] "GET /api/studies/6?after=18 HTTP/1.1" 200 776179
# 127.0.0.1 - - [27/Feb/2025 17:21:37] "GET /api/studies/6/param_importances HTTP/1.1" 200 1262
# 127.0.0.1 - - [27/Feb/2025 17:21:49] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:21:59] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:08] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:10] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:13] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:15] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:17] "GET /api/studies/6?after=19 HTTP/1.1" 200 315735
# 127.0.0.1 - - [27/Feb/2025 17:22:19] "GET /api/studies HTTP/1.1" 200 706
# 127.0.0.1 - - [27/Feb/2025 17:36:21] "GET /api/meta HTTP/1.1" 200 60
# 127.0.0.1 - - [27/Feb/2025 17:36:21] "GET /api/studies/6?after=19 HTTP/1.1" 200 9829452
# 127.0.0.1 - - [27/Feb/2025 17:36:22] "GET /api/studies/6/param_importances HTTP/1.1" 200 1260
# 127.0.0.1 - - [27/Feb/2025 17:36:32] "GET /api/studies/6?after=36 HTTP/1.1" 200 315709
# 127.0.0.1 - - [27/Feb/2025 17:36:42] "GET /api/studies/6?after=36 HTTP/1.1" 200 315709
HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:22:50] "GET /api/studies/6?after=102 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:23:07] "GET /api/studies/6?after=102 HTTP/1.1" 200 402768
# 127.0.0.1 - - [27/Feb/2025 18:23:07] "GET /api/studies/6/param_importances HTTP/1.1" 200 1253
# 127.0.0.1 - - [27/Feb/2025 18:23:18] "GET /api/studies/6?after=103 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:23:31] "GET /api/studies/6?after=103 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:23:45] "GET /api/studies/6?after=103 HTTP/1.1" 200 385730
# 127.0.0.1 - - [27/Feb/2025 18:23:46] "GET /api/studies/6/param_importances HTTP/1.1" 200 1258
# 127.0.0.1 - - [27/Feb/2025 18:24:03] "GET /api/studies/6?after=104 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:24:14] "GET /api/studies/6?after=104 HTTP/1.1" 200 380454
# 127.0.0.1 - - [27/Feb/2025 18:24:15] "GET /api/studies/6/param_importances HTTP/1.1" 200 1258
# 127.0.0.1 - - [27/Feb/2025 18:24:26] "GET /api/studies/6?after=105 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:24:37] "GET /api/studies/6?after=105 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:24:56] "GET /api/studies/6?after=105 HTTP/1.1" 200 421505
# 127.0.0.1 - - [27/Feb/2025 18:24:57] "GET /api/studies/6/param_importances HTTP/1.1" 200 1252
# 127.0.0.1 - - [27/Feb/2025 18:25:25] "GET /api/studies/6?after=106 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:25:43] "GET /api/studies/6?after=106 HTTP/1.1" 200 359059
# 127.0.0.1 - - [27/Feb/2025 18:25:43] "GET /api/studies/6/param_importances HTTP/1.1" 200 1254
# 127.0.0.1 - - [27/Feb/2025 18:25:58] "GET /api/studies/6?after=107 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:26:16] "GET /api/studies/6?after=107 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:26:40] "GET /api/studies/6?after=107 HTTP/1.1" 200 434552
# 127.0.0.1 - - [27/Feb/2025 18:26:40] "GET /api/studies/6/param_importances HTTP/1.1" 200 1255
# 127.0.0.1 - - [27/Feb/2025 18:26:59] "GET /api/studies/6?after=108 HTTP/1.1" 200 366069
# 127.0.0.1 - - [27/Feb/2025 18:27:00] "GET /api/studies/6/param_importances HTTP/1.1" 200 1257
# 127.0.0.1 - - [27/Feb/2025 18:27:20] "GET /api/studies/6?after=109 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:27:33] "GET /api/studies/6?after=109 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:27:44] "GET /api/studies/6?after=109 HTTP/1.1" 200 366513
# 127.0.0.1 - - [27/Feb/2025 18:27:45] "GET /api/studies/6/param_importances HTTP/1.1" 200 1253
# 127.0.0.1 - - [27/Feb/2025 18:27:55] "GET /api/studies/6?after=110 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:28:06] "GET /api/studies/6?after=110 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:28:17] "GET /api/studies/6?after=110 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:28:27] "GET /api/studies/6?after=110 HTTP/1.1" 200 338118
# 127.0.0.1 - - [27/Feb/2025 18:28:28] "GET /api/studies/6/param_importances HTTP/1.1" 200 1255
# 127.0.0.1 - - [27/Feb/2025 18:28:38] "GET /api/studies/6?after=111 HTTP/1.1" 200 190421
# 127.0.0.1 - - [27/Feb/2025 18:28:49] "GET /api/studies/6?after=111 HTTP/1.1" 200 190421
# 127.0.0.1 - - [27/Feb/2025 18:29:00] "GET /api/studies/6?after=111 HTTP/1.1" 200 190421
# 127.0.0.1 - - [27/Feb/2025 18:29:10] "GET /api/studies/6?after=111 HTTP/1.1" 200 419819
# 127.0.0.1 - - [27/Feb/2025 18:29:11] "GET /api/studies/6/param_importances HTTP/1.1" 200 1255
# 127.0.0.1 - - [27/Feb/2025 18:29:22] "GET /api/studies/6?after=112 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:29:37] "GET /api/studies/6?after=112 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:29:43] "GET /api/studies/6?after=112 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:29:48] "GET /api/studies/6?after=112 HTTP/1.1" 200 321534
# 127.0.0.1 - - [27/Feb/2025 18:29:55] "GET /api/studies/6?after=113 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:30:02] "GET /api/studies/6?after=113 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:30:18] "GET /api/studies/6?after=113 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:30:24] "GET /api/studies/6?after=113 HTTP/1.1" 200 419772
# 127.0.0.1 - - [27/Feb/2025 18:30:30] "GET /api/studies/6?after=114 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:30:36] "GET /api/studies/6?after=114 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:30:42] "GET /api/studies/6?after=114 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:30:48] "GET /api/studies/6?after=114 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:30:55] "GET /api/studies/6?after=114 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:01] "GET /api/studies/6?after=114 HTTP/1.1" 200 367401
# 127.0.0.1 - - [27/Feb/2025 18:31:07] "GET /api/studies/6?after=115 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:13] "GET /api/studies/6?after=115 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:19] "GET /api/studies/6?after=115 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:25] "GET /api/studies/6?after=115 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:31] "GET /api/studies/6?after=115 HTTP/1.1" 200 190387
# 127.0.0.1 - - [27/Feb/2025 18:31:37] "GET /api/studies/6?after=115 HTTP/1.1" 200 380468
# 127.0.0.1 - - [27/Feb/2025 18:31:43] "GET /api/studies/6?after=116 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:31:49] "GET /api/studies/6?after=116 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:31:55] "GET /api/studies/6?after=116 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:32:01] "GET /api/studies/6?after=116 HTTP/1.1" 200 190361
# 127.0.0.1 - - [27/Feb/2025 18:32:07] "GET /api/studies/6?after=116 HTTP/1.1" 200 315388
# 127.0.0.1 - - [27/Feb/2025 18:32:13] "GET /api/studies/6?after=117 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:32:19] "GET /api/studies/6?after=117 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:32:25] "GET /api/studies/6?after=117 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:32:31] "GET /api/studies/6?after=117 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:32:37] "GET /api/studies/6?after=117 HTTP/1.1" 200 190389
# 127.0.0.1 - - [27/Feb/2025 18:32:43] "GET /api/studies/6?after=117 HTTP/1.1" 200 314095
# 127.0.0.1 - - [27/Feb/2025 18:32:49] "GET /api/studies/6?after=118 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:32:56] "GET /api/studies/6?after=118 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:33:02] "GET /api/studies/6?after=118 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:33:08] "GET /api/studies/6?after=118 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:33:14] "GET /api/studies/6?after=118 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:33:21] "GET /api/studies/6?after=118 HTTP/1.1" 200 440941
# 127.0.0.1 - - [27/Feb/2025 18:33:27] "GET /api/studies/6?after=119 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:33:33] "GET /api/studies/6?after=119 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:33:39] "GET /api/studies/6?after=119 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:33:47] "GET /api/studies/6?after=119 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:33:52] "GET /api/studies/6?after=119 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:33:58] "GET /api/studies/6?after=119 HTTP/1.1" 200 396138
# 127.0.0.1 - - [27/Feb/2025 18:34:06] "GET /api/studies/6?after=120 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:34:15] "GET /api/studies/6?after=120 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:34:21] "GET /api/studies/6?after=120 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:34:28] "GET /api/studies/6?after=120 HTTP/1.1" 200 191103
# 127.0.0.1 - - [27/Feb/2025 18:34:34] "GET /api/studies/6?after=120 HTTP/1.1" 200 338999
# 127.0.0.1 - - [27/Feb/2025 18:34:44] "GET /api/studies/6?after=121 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:34:50] "GET /api/studies/6?after=121 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:34:56] "GET /api/studies/6?after=121 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:35:02] "GET /api/studies/6?after=121 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:35:08] "GET /api/studies/6?after=121 HTTP/1.1" 200 380491
# 127.0.0.1 - - [27/Feb/2025 18:35:14] "GET /api/studies/6?after=122 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:35:24] "GET /api/studies/6?after=122 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:35:34] "GET /api/studies/6?after=122 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:35:40] "GET /api/studies/6?after=122 HTTP/1.1" 200 190419
# 127.0.0.1 - - [27/Feb/2025 18:35:46] "GET /api/studies/6?after=122 HTTP/1.1" 200 409812
# 127.0.0.1 - - [27/Feb/2025 18:36:00] "GET /api/studies/6?after=123 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:36:05] "GET /api/studies/6?after=123 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:36:11] "GET /api/studies/6?after=123 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:36:20] "GET /api/studies/6?after=123 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:36:28] "GET /api/studies/6?after=123 HTTP/1.1" 200 513883
# 127.0.0.1 - - [27/Feb/2025 18:36:34] "GET /api/studies/6?after=124 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:36:42] "GET /api/studies/6?after=124 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:36:48] "GET /api/studies/6?after=124 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:36:54] "GET /api/studies/6?after=124 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:37:00] "GET /api/studies/6?after=124 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:37:09] "GET /api/studies/6?after=124 HTTP/1.1" 200 385692
# 127.0.0.1 - - [27/Feb/2025 18:37:16] "GET /api/studies/6?after=125 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:37:27] "GET /api/studies/6?after=125 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:37:34] "GET /api/studies/6?after=125 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:37:43] "GET /api/studies/6?after=125 HTTP/1.1" 200 320682
# 127.0.0.1 - - [27/Feb/2025 18:37:48] "GET /api/studies/6?after=126 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:37:54] "GET /api/studies/6?after=126 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:38:02] "GET /api/studies/6?after=126 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:38:10] "GET /api/studies/6?after=126 HTTP/1.1" 200 190391
# 127.0.0.1 - - [27/Feb/2025 18:38:16] "GET /api/studies/6?after=126 HTTP/1.1" 200 367392
# 127.0.0.1 - - [27/Feb/2025 18:38:25] "GET /api/studies/6?after=127 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:38:33] "GET /api/studies/6?after=127 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:38:42] "GET /api/studies/6?after=127 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:38:50] "GET /api/studies/6?after=127 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:38:59] "GET /api/studies/6?after=127 HTTP/1.1" 200 190359
# 127.0.0.1 - - [27/Feb/2025 18:39:02] "GET /api/studies HTTP/1.1" 200 706
# 127.0.0.1 - - [27/Feb/2025 19:21:20] "GET /api/meta HTTP/1.1" 200 60
# 127.0.0.1 - - [27/Feb/2025 19:21:26] "GET /api/studies/6?after=127 HTTP/1.1" 200 13116854
# 127.0.0.1 - - [27/Feb/2025 19:21:28] "GET /api/studies/6/param_importances HTTP/1.1" 200 1254
# 127.0.0.1 - - [27/Feb/2025 19:21:28] "GET /api/studies/6/param_importances HTTP/1.1" 200 1254
# 127.0.0.1 - - [27/Feb/2025 19:21:38] "GET /api/studies/6?after=195 HTTP/1.1" 200 179487
# 127.0.0.1 - - [27/Feb/2025 19:21:49] "GET /api/studies/6?after=195 HTTP/1.1" 200 179487
# 127.0.0.1 - - [27/Feb/2025 19:22:01] "GET /api/studies/6?after=195 HTTP/1.1" 200 308056
# 127.0.0.1 - - [27/Feb/2025 19:22:02] "GET /api/studies/6/param_importances HTTP/1.1" 200 1252
# 127.0.0.1 - - [27/Feb/2025 19:22:11] "GET /api/studies/6?after=196 HTTP/1.1" 200 179515
# 127.0.0.1 - - [27/Feb/2025 19:22:23] "GET /api/studies/6?after=196 HTTP/1.1" 200 179515
# 127.0.0.1 - - [27/Feb/2025 19:22:33] "GET /api/studies/6?after=196 HTTP/1.1" 200 179515
# 127.0.0.1 - - [27/Feb/2025 19:22:44] "GET /api/studies/6?after=196 HTTP/1.1" 200 343474
# 127.0.0.1 - - [27/Feb/2025 19:22:45] "GET /api/studies/6/param_importances HTTP/1.1" 200 1253
# 127.0.0.1 - - [27/Feb/2025 19:22:55] "GET /api/studies/6?after=197 HTTP/1.1" 200 179515
# 127.0.0.1 - - [27/Feb/2025 19:23:06] "GET /api/studies/6?after=197 HTTP/1.1" 200 179515
# 127.0.0.1 - - [27/Feb/2025 19:23:17] "GET /api/studies/6?after=197 HTTP/1.1" 200 304127
# 127.0.0.1 - - [27/Feb/2025 19:23:17] "GET /api/studies/6/param_importances HTTP/1.1" 200 1252
# ...
# 127.0.0.1 - - [28/Feb/2025 17:27:47] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:16] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:16] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:32] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:32] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:49] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:28:49] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:22] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:22] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:25] "GET /api/studies/6/param_importances HTTP/1.1" 200 1257
# 127.0.0.1 - - [28/Feb/2025 17:29:38] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:29:59] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:00] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:00] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:41] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:41] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:57] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:30:57] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:13] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:13] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:28] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:28] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:57] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:31:57] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:13] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:13] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:28] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:28] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:56] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:32:56] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:10] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:10] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:25] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:33:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:09] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:09] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:23] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:23] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:38] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:38] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:52] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:34:52] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:06] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:06] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:35] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:35] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:50] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:35:50] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:04] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:04] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:19] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:19] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:47] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:36:47] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:00] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:00] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:16] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:16] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:31] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:31] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:47] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:37:47] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:17] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:17] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:48] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:38:48] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:02] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:02] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:36] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:36] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:53] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:39:53] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:09] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:09] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:27] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:27] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:44] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:40:44] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:03] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:03] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:20] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:36] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:36] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:41:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:10] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:10] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:26] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:26] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:41] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:41] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:58] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:42:58] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:33] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:34] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:44] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:52] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:43:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:23] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:24] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:55] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:44:55] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:12] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:12] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:27] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:27] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:45:42] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:05] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:21] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:21] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:38] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:39] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:46:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:24] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:24] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:47:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:48:07] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:48:07] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:48:07] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:48:07] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:49:06] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:49:06] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:49:40] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:01] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:08] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:17] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:17] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:46] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:46] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:54] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:56] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:50:56] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:51:13] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084
# 127.0.0.1 - - [28/Feb/2025 17:51:29] "GET /api/studies/6?after=1730 HTTP/1.1" 200 185084

# %%
# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

import optuna
from optuna.storages import RDBStorage

# Define TimescaleDB configuration
timescale_config = {
    "host": "localhost",
    "port": 5433,
    "user": "backtest_user",
    "password": "backtest_password",
    "database": "backtest_db"
}

# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

# Create the optimizer with correct parameters
optimizer = StrategyOptimizer(
    root_path=root_path,
    storage_name="sqlite:///optuna.db",  # Using SQLite for now
    load_cached_data=False,
    resolution="1m"
)

# %%
# Create the optimizer
optimizer = StrategyOptimizer(root_path=root_path)

# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"oro3_optimization",
    config_generator=config_generator,
    n_trials=5000,
)
optimizer.get_study_best_params(f"oro3_optimization")
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[7], line 8
#       5 optimizer.launch_optuna_dashboard()
#       7 # Run the optimization
# ----> 8 await optimizer.optimize(
#       9     study_name=f"oro3_optimization",
#      10     config_generator=config_generator,
#      11     n_trials=5000,
#      12 )
#      13 optimizer.get_study_best_params(f"oro3_optimization")
#
# File ~/quants-lab/core/backtesting/optimizer.py:226, in StrategyOptimizer.optimize(self, study_name, config_generator, n_trials, load_if_exists)
#     224 study = self._create_study(study_name, load_if_exists=load_if_exists)
#     225 logger.info("About to start optimizing...")
# --> 226 await self._optimize_async(study, config_generator, n_trials=n_trials)
#
# File ~/quants-lab/core/backtesting/optimizer.py:256, in StrategyOptimizer._optimize_async(self, study, config_generator, n_trials)
#     252 trial = study.ask()
#     254 try:
#     255     # Run the async objective function and get the result
# --> 256     value = await self._async_objective(trial, config_generator)
#     258     # Report the result back to the study
#     259     study.tell(trial, value)
#
# File ~/quants-lab/core/backtesting/optimizer.py:341, in StrategyOptimizer._async_objective(self, trial, config_generator)
#     338 backtesting_config = await config_generator.generate_config(trial)
#     340 # Await the backtesting result
# --> 341 backtesting_result = await self._backtesting_engine.run_backtesting(
#     342     config=backtesting_config.config,
#     343     start=backtesting_config.start,
#     344     end=backtesting_config.end,
#     345     backtesting_resolution=self.resolution,
#     346 )
#     347 strategy_analysis = backtesting_result.results
#     349 for key, value in strategy_analysis.items():
#
# File ~/quants-lab/core/backtesting/engine.py:75, in BacktestingEngine.run_backtesting(self, config, start, end, backtesting_resolution, trade_cost)
#      73 async def run_backtesting(self, config: ControllerConfigBase, start: int,
#      74                           end: int, backtesting_resolution: str, trade_cost: float = 0.0006) -> BacktestingResult:
# ---> 75     bt_result = await self._bt_engine.run_backtesting(config, start, end, backtesting_resolution, trade_cost)
#      76     return BacktestingResult(bt_result, config)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py:92, in BacktestingEngineBase.run_backtesting(self, controller_config, start, end, backtesting_resolution, trade_cost)
#      89 self.controller = controller_class(config=controller_config, market_data_provider=self.backtesting_data_provider,
#      90                                    actions_queue=None)
#      91 self.backtesting_resolution = backtesting_resolution
# ---> 92 await self.initialize_backtesting_data_provider()
#      93 await self.controller.update_processed_data()
#      94 executors_info = await self.simulate_execution(trade_cost=trade_cost)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_engine_base.py:108, in BacktestingEngineBase.initialize_backtesting_data_provider(self)
#     102 async def initialize_backtesting_data_provider(self):
#     103     backtesting_config = CandlesConfig(
#     104         connector=self.controller.config.connector_name,
#     105         trading_pair=self.controller.config.trading_pair,
#     106         interval=self.backtesting_resolution
#     107     )
# --> 108     await self.controller.market_data_provider.initialize_candles_feed(backtesting_config)
#     109     for config in self.controller.config.candles_config:
#     110         await self.controller.market_data_provider.initialize_candles_feed(config)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_data_provider.py:81, in BacktestingDataProvider.initialize_candles_feed(self, config)
#      80 async def initialize_candles_feed(self, config: CandlesConfig):
# ---> 81     await self.get_candles_feed(config)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/strategy_v2/backtesting/backtesting_data_provider.py:106, in BacktestingDataProvider.get_candles_feed(self, config)
#     104 candle_feed = CandlesFactory.get_candle(config)
#     105 candles_buffer = config.max_records * CandlesBase.interval_to_seconds[config.interval]
# --> 106 candles_df = await candle_feed.get_historical_candles(config=HistoricalCandlesConfig(
#     107     connector_name=config.connector,
#     108     trading_pair=config.trading_pair,
#     109     interval=config.interval,
#     110     start_time=self.start_time - candles_buffer,
#     111     end_time=self.end_time,
#     112 ))
#     113 self.candles_feeds[key] = candles_df
#     114 return candles_df
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:172, in CandlesBase.get_historical_candles(self, config)
#     170 while current_end_time >= current_start_time:
#     171     missing_records = int((current_end_time - current_start_time) / self.interval_in_seconds)
# --> 172     candles = await self.fetch_candles(start_time=current_start_time,
#     173                                        end_time=current_end_time,
#     174                                        limit=missing_records)
#     175     if len(candles) <= 1 or missing_records == 0:
#     176         break
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/data_feed/candles_feed/candles_base.py:257, in CandlesBase.fetch_candles(self, start_time, end_time, limit)
#     255 headers = self._get_rest_candles_headers()
#     256 rest_assistant = await self._api_factory.get_rest_assistant()
# --> 257 candles = await rest_assistant.execute_request(url=self.candles_url,
#     258                                                throttler_limit_id=self._rest_throttler_limit_id,
#     259                                                params=params,
#     260                                                data=self._rest_payload(**kwargs),
#     261                                                headers=headers,
#     262                                                method=self._rest_method)
#     263 arr = self._parse_rest_candles(candles, end_time)
#     264 return np.array(arr).astype(float)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/core/web_assistant/rest_assistant.py:47, in RESTAssistant.execute_request(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      35 async def execute_request(
#      36     self,
#      37     url: str,
#    (...)
#      45     headers: Optional[Dict[str, Any]] = None,
#      46 ) -> Union[str, Dict[str, Any]]:
# ---> 47     response = await self.execute_request_and_get_response(
#      48         url=url,
#      49         throttler_limit_id=throttler_limit_id,
#      50         params=params,
#      51         data=data,
#      52         method=method,
#      53         is_auth_required=is_auth_required,
#      54         return_err=return_err,
#      55         timeout=timeout,
#      56         headers=headers,
#      57     )
#      58     response_json = await response.json()
#      59     return response_json
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/core/web_assistant/rest_assistant.py:94, in RESTAssistant.execute_request_and_get_response(self, url, throttler_limit_id, params, data, method, is_auth_required, return_err, timeout, headers)
#      83 request = RESTRequest(
#      84     method=method,
#      85     url=url,
#    (...)
#      90     throttler_limit_id=throttler_limit_id
#      91 )
#      93 async with self._throttler.execute_task(limit_id=throttler_limit_id):
# ---> 94     response = await self.call(request=request, timeout=timeout)
#      96     if 400 <= response.status:
#      97         if not return_err:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/core/web_assistant/rest_assistant.py:108, in RESTAssistant.call(self, request, timeout)
#     106 request = await self._pre_process_request(request)
#     107 request = await self._authenticate(request)
# --> 108 resp = await wait_for(self._connection.call(request), timeout)
#     109 resp = await self._post_process_response(resp)
#     110 return resp
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/asyncio/tasks.py:408, in wait_for(fut, timeout)
#     405 loop = events.get_running_loop()
#     407 if timeout is None:
# --> 408     return await fut
#     410 if timeout <= 0:
#     411     fut = ensure_future(fut, loop=loop)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/hummingbot/core/web_assistant/connections/rest_connection.py:10, in RESTConnection.call(self, request)
#       9 async def call(self, request: RESTRequest) -> RESTResponse:
# ---> 10     aiohttp_resp = await self._client_session.request(
#      11         method=request.method.value,
#      12         url=request.url,
#      13         params=request.params,
#      14         data=request.data,
#      15         headers=request.headers,
#      16     )
#      18     resp = await self._build_resp(aiohttp_resp)
#      19     return resp
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/aiohttp/client.py:703, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     701 # connection timeout
#     702 try:
# --> 703     conn = await self._connector.connect(
#     704         req, traces=traces, timeout=real_timeout
#     705     )
#     706 except asyncio.TimeoutError as exc:
#     707     raise ConnectionTimeoutError(
#     708         f"Connection timeout to host {url}"
#     709     ) from exc
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/aiohttp/connector.py:548, in BaseConnector.connect(self, req, traces, timeout)
#     546     for trace in traces:
#     547         await trace.send_connection_create_start()
# --> 548 proto = await self._create_connection(req, traces, timeout)
#     549 if traces:
#     550     for trace in traces:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/aiohttp/connector.py:1056, in TCPConnector._create_connection(self, req, traces, timeout)
#    1054     _, proto = await self._create_proxy_connection(req, traces, timeout)
#    1055 else:
# -> 1056     _, proto = await self._create_direct_connection(req, traces, timeout)
#    1058 return proto
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/aiohttp/connector.py:1351, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1346 assert port is not None
#    1347 try:
#    1348     # Cancelling this lookup should not cancel the underlying lookup
#    1349     #  or else the cancel event will get broadcast to all the waiters
#    1350     #  across all connections.
# -> 1351     hosts = await self._resolve_host(host, port, traces=traces)
#    1352 except OSError as exc:
#    1353     if exc.errno is None and isinstance(exc, asyncio.TimeoutError):
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/aiohttp/connector.py:995, in TCPConnector._resolve_host(self, host, port, traces)
#     992     resolved_host_task.add_done_callback(self._resolve_host_tasks.discard)
#     994 try:
# --> 995     return await asyncio.shield(resolved_host_task)
#     996 except asyncio.CancelledError:
#     998     def drop_exception(fut: "asyncio.Future[List[ResolveResult]]") -> None:
#
# CancelledError:

# %%
# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"elitesmugplug1 ",
    config_generator=config_generator,
    n_trials=10000,
)
optimizer.get_study_best_params(f"elitesmugplug1")

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer
from research_notebooks.elitesmugplug.elitesmugplug_config_gen_simple import SmugPlug3LiteConfigGenerator

# Define the date range for the optimization
start_date = datetime.datetime(2025, 1, 1)
end_date = datetime.datetime(2025, 2, 1)

# Database configuration for Docker container
timescale_config = {
    "host": "localhost",  # or your Docker host IP
    "port": 5432,        # exposed port from docker-compose
    "user": "admin",     # from docker-compose
    "password": "admin", # from docker-compose
    "database": "timescaledb"
}

# Create the configuration generator
config_generator = SmugPlug3LiteConfigGenerator(
    start_date=start_date, 
    end_date=end_date,
    timescale_config=timescale_config
)

# Create the optimizer with database connection
optimizer = StrategyOptimizer(
    root_path=root_path,
    db_host=timescale_config["host"],
    db_port=timescale_config["port"],
    db_user=timescale_config["user"],
    db_pass=timescale_config["password"]
)

# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"smugplug_optimization",
    config_generator=config_generator,
    n_trials=100,
)
