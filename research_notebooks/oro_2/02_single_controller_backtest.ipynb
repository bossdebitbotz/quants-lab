# %%
# This is necessary to recognize the modules
import os
import sys
from decimal import Decimal
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.backtesting import BacktestingEngine

backtesting = BacktestingEngine(root_path=root_path, load_cached_data=False)

# %%
from hummingbot.strategy_v2.executors.position_executor.data_types import TrailingStop
from controllers.directional_trading.oro_2 import Oro2ControllerConfig
import datetime
from decimal import Decimal


# Controller configuration
connector_name = "binance_perpetual"
trading_pair = "WLD-USDT"
interval = "1m"
total_amount_quote = 1000
max_executors_per_side = 1
take_profit = 0.05
stop_loss = 0.05
trailing_stop_activation_price = 0.05
trailing_stop_trailing_delta = 0.001
time_limit = 60 * 60 * 8  # 8 hours
cooldown_time = 60  # 1 minute

# Oro2 specific parameters
macd_fast = 12
macd_slow = 39
macd_signal = 9
ema_short = 8
ema_medium = 23
ema_long = 47
atr_length = 5
atr_multiplier = 1.1
pivot_lookback = 20
pivot_threshold = 0.45



# Creating the instance of the configuration and the controller
config = Oro2ControllerConfig(
    connector_name=connector_name,
    trading_pair=trading_pair,
    interval=interval,
    macd_fast=macd_fast,
    macd_slow=macd_slow,
    macd_signal=macd_signal,
    ema_short=ema_short,
    ema_medium=ema_medium,
    ema_long=ema_long,
    atr_length=atr_length,
    atr_multiplier=atr_multiplier,
    pivot_lookback=pivot_lookback,
    pivot_threshold=Decimal(pivot_threshold),
    
    total_amount_quote=Decimal(total_amount_quote),
    take_profit=Decimal(take_profit),
    stop_loss=Decimal(stop_loss),
    trailing_stop=TrailingStop(
        activation_price=Decimal(trailing_stop_activation_price),
        trailing_delta=Decimal(trailing_stop_trailing_delta)
    ),
    time_limit=time_limit,
    max_executors_per_side=max_executors_per_side,
    cooldown_time=cooldown_time,
)

# %%
# Running the backtesting this will output a backtesting result object that has built in methods to visualize the results

start = int(datetime.datetime(2025, 1, 1).timestamp())
end = int(datetime.datetime(2025, 1, 30).timestamp())


backtesting_result = await backtesting.run_backtesting(config, start, end, "1m")
# Out:
# 2025-03-01 22:11:12,908 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x15d9373d0>
# 2025-03-01 22:11:12,909 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x15d917ee0>, 357715.762746291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x15d937040>
# 2025-03-01 22:11:21,252 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x15db839a0>
# 2025-03-01 22:11:21,256 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x15db67d00>, 357724.104082625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x15db839d0>
# 2025-03-01 22:11:28,183 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x15db83dc0>
# 2025-03-01 22:11:28,184 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x15db67f40>, 357731.035557333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x15db83d90>

# %%
# Let's see what is inside the backtesting results
print(backtesting_result.get_results_summary())
backtesting_result.get_backtesting_figure()
# Out:
# Net PNL: $-16.82 (-1.68%) | Max Drawdown: $-276.33 (-27.07%)
# Total Volume ($): 318000.00 | Sharpe Ratio: 0.66 | Profit Factor: 0.99
# Total Executors: 159 | Accuracy Long: 0.43 | Accuracy Short: 0.55
# Close Types: Take Profit: 31 | Stop Loss: 31 | Time Limit: 97 |
#              Trailing Stop: 0 | Early Stop: 0

# %%
# 2. The executors dataframe: this is the dataframe that contains the information of the orders that were executed
import pandas as pd

executors_df = backtesting_result.executors_df
executors_df.head()
# Out:
#                                              id  timestamp               type  \
# 0  3qJTMfsLGD4QVefssUuSBHrFdE6cHHjnyEB1LTWQyE4Y 1735710360  position_executor
# 1  8cjbk5R5P9N4XhtYqJtxQbcVe8xBT3PLXdGGTvhuMmKA 1735739160  position_executor
# 2  9C9UosfFjbvhMFa58TxDyYShDVS6PtVaJUxXRpPfLDiX 1735768080  position_executor
# 3  8KhocxVPMtg9MqMLTBZW9vdnhrHPht9SMK9hNYQhmyyb 1735796880  position_executor
# 4  3tiEFSHKrFhrqXW9ewcRwRo3ZDMt4w38hUzhEcnqg1XX 1735801920  position_executor
#
#    close_timestamp            close_type                     status  \
# 0       1735739160  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 1       1735767960  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 2       1735796880  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 3       1735825680  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
# 4       1735830720  CloseType.TIME_LIMIT  RunnableStatus.TERMINATED
#
#                                               config  \
# 0  {'id': '3qJTMfsLGD4QVefssUuSBHrFdE6cHHjnyEB1LT...
# 1  {'id': '8cjbk5R5P9N4XhtYqJtxQbcVe8xBT3PLXdGGTv...
# 2  {'id': '9C9UosfFjbvhMFa58TxDyYShDVS6PtVaJUxXRp...
# 3  {'id': '8KhocxVPMtg9MqMLTBZW9vdnhrHPht9SMK9hNY...
# 4  {'id': '3tiEFSHKrFhrqXW9ewcRwRo3ZDMt4w38hUzhEc...
#
#                                          net_pnl_pct  \
# 0  0.02066656292733630786995213668433279963210225...
# 1  0.01366724535968348933079319351691083284094929...
# 2  0.03398475540386740323395287077801185660064220...
# 3  -0.0196895095667493739977071953717313590459525...
# 4  0.01100174687899839812144087147771642776206135...
#
#                                        net_pnl_quote  \
# 0  20.6665629273363045115274871932342648506164550...
# 1  13.6672453596834877487253834260627627372741699...
# 2   33.984755403867410450402530841529369354248046875
# 3  -19.689509566749375579775005462579429149627685...
# 4  11.0017468789983983157299007871188223361968994...
#
#                                       cum_fees_quote  \
# 0  0.59999999999999986677323704498121514916419982...
# 1  0.59999999999999986677323704498121514916419982...
# 2  0.59999999999999997779553950749686919152736663...
# 3  0.59999999999999997779553950749686919152736663...
# 4  0.59999999999999997779553950749686919152736663...
#
#                                filled_amount_quote  is_active  is_trading  \
# 0  1999.999999999999772626324556767940521240234375      False       False
# 1  1999.999999999999772626324556767940521240234375      False       False
# 2  2000.000000000000227373675443232059478759765625      False       False
# 3                                             2000      False       False
# 4                                             2000      False       False
#
#                                          custom_info controller_id  side
# 0  {'close_price': 2.1658, 'level_id': None, 'sid...          None   BUY
# 1  {'close_price': 2.1967, 'level_id': None, 'sid...          None   BUY
# 2  {'close_price': 2.2735, 'level_id': None, 'sid...          None   BUY
# 3  {'close_price': 2.3169, 'level_id': None, 'sid...          None  SELL
# 4  {'close_price': 2.2932, 'level_id': None, 'sid...          None   BUY

# %% [markdown]
# ### Backtesting Analysis

# %% [markdown]
# ### Scatter of PNL per Trade
# This bar chart illustrates the PNL for each individual trade. Positive PNLs are shown in green and negative PNLs in red, providing a clear view of profitable vs. unprofitable trades.

# %%
import plotly.express as px

# Create a new column for profitability
executors_df['profitable'] = executors_df['net_pnl_quote'] > 0

# Create the scatter plot
fig = px.scatter(
    executors_df,
    x="timestamp",
    y='net_pnl_quote',
    title='PNL per Trade',
    color='profitable',
    color_discrete_map={True: 'green', False: 'red'},
    labels={'timestamp': 'Timestamp', 'net_pnl_quote': 'Net PNL (Quote)'},
    hover_data=['filled_amount_quote', 'side']
)

# Customize the layout
fig.update_layout(
    xaxis_title="Timestamp",
    yaxis_title="Net PNL (Quote)",
    legend_title="Profitable",
    font=dict(size=12, color="white"),
    showlegend=False,
    plot_bgcolor='rgba(0,0,0,0.8)',  # Dark background
    paper_bgcolor='rgba(0,0,0,0.8)',  # Dark background for the entire plot area
    xaxis=dict(gridcolor="gray"),
    yaxis=dict(gridcolor="gray")
)

# Add a horizontal line at y=0 to clearly separate profits and losses
fig.add_hline(y=0, line_dash="dash", line_color="lightgray")

# Show the plot
fig.show()

# %% [markdown]
# ### Histogram of PNL Distribution
# The histogram displays the distribution of PNL values across all trades. It helps in understanding the frequency and range of profit and loss outcomes.

# %%
fig = px.histogram(executors_df, x='net_pnl_quote', title='PNL Distribution')
fig.show()

# %% [markdown]
# # Conclusion
# We can see that the indicator has potential to bring good signals to trade and might be interesting to see how we can design a market maker that shifts the mid price based on this indicator.
# A lot of the short signals are wrong but if we zoom in into the loss signals we can see that the losses are not that big and the wins are bigger and if we had implemented the trailing stop feature probably a lot of them are going to be profits.

# %% [markdown]
# # Next steps
# - Filter only the loss signals and understand what you can do to prevent them
# - Try different configuration values for the indicator
# - Test in multiple markets, pick mature markets like BTC-USDT or ETH-USDT and also volatile markets like DOGE-USDT or SHIB-USDT
