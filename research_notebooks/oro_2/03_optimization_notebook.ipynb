# %%
# This is necessary to recognize the modules
import os
import sys
import warnings

warnings.filterwarnings("ignore")

root_path = os.path.abspath(os.path.join(os.getcwd(), '../..'))
sys.path.append(root_path)

# %%
from core.services.timescale_client import TimescaleClient

# Create test connection to the new backtesting database
ts_client = TimescaleClient(
    host="localhost",
    port=5433,  # Using the new port we specified
    user="backtest_user",
    password="backtest_password",
    database="backtest_db"
)

# Test connection
await ts_client.connect()

# %%
import datetime
from core.backtesting.optimizer import StrategyOptimizer

# %%
from research_notebooks.oro_2.oro_2_config_gen_simple import Oro2ConfigGenerator

# Define the date range for the optimization
start_date = datetime.datetime(2025, 1, 1)
end_date = datetime.datetime(2025, 2, 22)

# Create the configuration generator
config_generator = Oro2ConfigGenerator(start_date=start_date, end_date=end_date)

# %%
if 'optimizer' in globals():
    await optimizer.close()

# Clean up any stale connections without deleting data
import sqlite3

def unlock_database():
    try:
        # Force close any existing connections
        conn = sqlite3.connect('optuna.db')
        conn.execute("PRAGMA busy_timeout = 5000")
        conn.execute("PRAGMA journal_mode = DELETE")
        conn.close()
        print("Database unlocked successfully")
    except Exception as e:
        print(f"Error during unlock: {str(e)}")

unlock_database()
# Out:
# Database unlocked successfully

# %%
# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

import optuna
from optuna.storages import RDBStorage

# Define TimescaleDB configuration
timescale_config = {
    "host": "localhost",
    "port": 5433,
    "user": "backtest_user",
    "password": "backtest_password",
    "database": "backtest_db"
}

# First, close any existing connections
if 'optimizer' in globals():
    await optimizer.close()

# Create the optimizer with correct parameters
optimizer = StrategyOptimizer(
    root_path=root_path,
    storage_name="sqlite:///optuna.db",  # Using SQLite for now
    load_cached_data=False,
    resolution="1m"
)

# %%
# Create the optimizer
optimizer = StrategyOptimizer(root_path=root_path)

# Launch the Optuna dashboard
optimizer.launch_optuna_dashboard()

# Run the optimization
await optimizer.optimize(
    study_name=f"new_oro3_optimization",
    config_generator=config_generator,
    n_trials=5000,
)
optimizer.get_study_best_params(f"new_oro3_optimization")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1740852134.505214 7881980 fork_posix.cc:75] Other threads are currently calling into gRPC, skipping fork() handlers
# 2025-03-01 13:02:14,663 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14ecf0cd0>
# [I 2025-03-01 13:02:14,760] A new study created in RDB with name: new_oro3_optimization
# 2025-03-01 13:02:15,560 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f910940>
# 2025-03-01 13:02:15,561 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f2cf0a0>, 324777.978445291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f912f20>
# Listening on http://127.0.0.1:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [01/Mar/2025 13:02:27] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:02:28,289 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fa293f0>
# 2025-03-01 13:02:28,292 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f588ac0>, 324790.70364125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fa29420>
# 2025-03-01 13:02:40,974 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fa2a020>
# 2025-03-01 13:02:40,987 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f588ac0>, 324803.371465166)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fa2b3a0>
# 127.0.0.1 - - [01/Mar/2025 13:02:42] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:02:58] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:03:13] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:03:26,282 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309bd6b00>
# 2025-03-01 13:03:26,285 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f503be0>, 324848.69549675)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309bd5a50>
# 127.0.0.1 - - [01/Mar/2025 13:03:28] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:03:37,830 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f9ff7c0>
# 2025-03-01 13:03:37,831 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14edcf820>, 324860.245617708)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fa2bb80>
# 127.0.0.1 - - [01/Mar/2025 13:03:43] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:03:58] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:04:12] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:04:27] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:04:41] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:04:46,590 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309e22290>
# 2025-03-01 13:04:46,593 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x105427d00>, 324929.003884041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309e22bf0>
# 127.0.0.1 - - [01/Mar/2025 13:04:56] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:04:59,127 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fb183a0>
# 2025-03-01 13:04:59,128 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f1bc0a0>, 324941.5435615)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fb18340>
# 127.0.0.1 - - [01/Mar/2025 13:05:10] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:05:25] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:05:38] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:05:42,639 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f971b70>
# 2025-03-01 13:05:42,641 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f1bc0a0>, 324985.055483208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f973f10>
# 127.0.0.1 - - [01/Mar/2025 13:05:52] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:05:54,206 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f9c9db0>
# 2025-03-01 13:05:54,207 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f2cf0a0>, 324996.620252083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f9cb0a0>
# 127.0.0.1 - - [01/Mar/2025 13:06:06] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:06:20] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:06:34] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:06:48] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:06:53,656 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309418220>
# 2025-03-01 13:06:53,657 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f2cf0a0>, 325056.0683125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309419f90>
# 127.0.0.1 - - [01/Mar/2025 13:07:01] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 2025-03-01 13:07:05,137 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fb1b9a0>
# 2025-03-01 13:07:05,138 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92a740>, 325067.554418041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fb18280>
# 127.0.0.1 - - [01/Mar/2025 13:07:15] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:07:29] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:07:42] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:07:58] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:08:12] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:08:26] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:08:40] "GET /api/studies/8?after=1028 HTTP/1.1" 200 382205
# 127.0.0.1 - - [01/Mar/2025 13:08:44] "GET /api/studies HTTP/1.1" 200 942
# 127.0.0.1 - - [01/Mar/2025 13:08:46] "GET /api/meta HTTP/1.1" 200 60
# /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna_dashboard/_importance.py:75: ExperimentalWarning: PedAnovaImportanceEvaluator is experimental (supported from v3.6.0). The interface can change in the future.
#   return get_param_importances(study, target=target, evaluator=PedAnovaImportanceEvaluator())
# 127.0.0.1 - - [01/Mar/2025 13:08:46] "GET /api/studies/9?after=0 HTTP/1.1" 200 2281153
# /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/importance/_ped_anova/evaluator.py:150: UserWarning: PedAnovaImportanceEvaluator computes the importances of params to achieve low `target` values. If this is not what you want, please modify target, e.g., by multiplying the output by -1.
#   warnings.warn(
# 127.0.0.1 - - [01/Mar/2025 13:08:46] "GET /api/studies/9/param_importances HTTP/1.1" 200 1422
# 127.0.0.1 - - [01/Mar/2025 13:08:46] "GET /api/studies/9/param_importances HTTP/1.1" 200 1422
# 127.0.0.1 - - [01/Mar/2025 13:08:56] "GET /api/studies/9?after=4 HTTP/1.1" 200 490727
# 127.0.0.1 - - [01/Mar/2025 13:09:06] "GET /api/studies/9?after=4 HTTP/1.1" 200 2182278
# 127.0.0.1 - - [01/Mar/2025 13:09:06] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 127.0.0.1 - - [01/Mar/2025 13:09:17] "GET /api/studies/9?after=5 HTTP/1.1" 200 490665
# 2025-03-01 13:09:18,386 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309983670>
# 2025-03-01 13:09:18,387 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92a740>, 325200.753011)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309f8a200>
# 2025-03-01 13:09:30,047 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309f89cf0>
# 2025-03-01 13:09:30,049 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309b86980>, 325212.412468)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309f8a6e0>
# 127.0.0.1 - - [01/Mar/2025 13:09:34] "GET /api/studies/9?after=5 HTTP/1.1" 200 490665
# 127.0.0.1 - - [01/Mar/2025 13:09:45] "GET /api/studies/9?after=5 HTTP/1.1" 200 490665
# 127.0.0.1 - - [01/Mar/2025 13:09:56] "GET /api/studies/9?after=5 HTTP/1.1" 200 772753
# 127.0.0.1 - - [01/Mar/2025 13:09:56] "GET /api/studies/9/param_importances HTTP/1.1" 200 1430
# 2025-03-01 13:10:06,115 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3093c4970>
# 2025-03-01 13:10:06,117 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x11eb89660>, 325248.486103458)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3093c4580>
# 127.0.0.1 - - [01/Mar/2025 13:10:07] "GET /api/studies/9?after=6 HTTP/1.1" 200 490669
# 2025-03-01 13:10:18,209 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309ff67d0>
# 2025-03-01 13:10:18,211 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x1052c6440>, 325260.57860325)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309ff7190>
# 127.0.0.1 - - [01/Mar/2025 13:10:18] "GET /api/studies/9?after=6 HTTP/1.1" 200 490669
# 127.0.0.1 - - [01/Mar/2025 13:10:29] "GET /api/studies/9?after=6 HTTP/1.1" 200 490669
# 127.0.0.1 - - [01/Mar/2025 13:10:40] "GET /api/studies/9?after=6 HTTP/1.1" 200 490669
# 127.0.0.1 - - [01/Mar/2025 13:10:51] "GET /api/studies/9?after=6 HTTP/1.1" 200 549874
# 127.0.0.1 - - [01/Mar/2025 13:10:51] "GET /api/studies/9/param_importances HTTP/1.1" 200 1426
# 2025-03-01 13:10:58,318 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f418670>
# 2025-03-01 13:10:58,320 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x1052c6440>, 325300.684080583)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f418280>
# 127.0.0.1 - - [01/Mar/2025 13:11:02] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 2025-03-01 13:11:10,308 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3099f3070>
# 2025-03-01 13:11:10,311 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x1052c6440>, 325312.673165458)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3099f0fa0>
# 127.0.0.1 - - [01/Mar/2025 13:11:13] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:11:24] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:11:35] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:11:46] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:11:57] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:12:08] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:12:19] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:12:30] "GET /api/studies/9?after=7 HTTP/1.1" 200 278874
# 127.0.0.1 - - [01/Mar/2025 13:12:41] "GET /api/studies/9?after=7 HTTP/1.1" 200 1387875
# 127.0.0.1 - - [01/Mar/2025 13:12:41] "GET /api/studies/9/param_importances HTTP/1.1" 200 1424
# 2025-03-01 13:12:51,200 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f971fc0>
# 2025-03-01 13:12:51,206 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x1052c6440>, 325413.56578125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f973670>
# 127.0.0.1 - - [01/Mar/2025 13:12:52] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 2025-03-01 13:13:03,471 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a30130>
# 2025-03-01 13:13:03,473 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309f85240>, 325425.839183416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a31960>
# 127.0.0.1 - - [01/Mar/2025 13:13:03] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 127.0.0.1 - - [01/Mar/2025 13:13:14] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 127.0.0.1 - - [01/Mar/2025 13:13:25] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 127.0.0.1 - - [01/Mar/2025 13:13:36] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 127.0.0.1 - - [01/Mar/2025 13:13:47] "GET /api/studies/9?after=8 HTTP/1.1" 200 278876
# 127.0.0.1 - - [01/Mar/2025 13:13:58] "GET /api/studies/9?after=8 HTTP/1.1" 200 812814
# 127.0.0.1 - - [01/Mar/2025 13:13:58] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:14:06,146 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3093c49a0>
# 2025-03-01 13:14:06,147 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f9c4ac0>, 325488.514622)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3093c6ad0>
# 127.0.0.1 - - [01/Mar/2025 13:14:09] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 2025-03-01 13:14:18,008 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fa2a140>
# 2025-03-01 13:14:18,009 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f9c4ac0>, 325500.380779666)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fa289d0>
# 127.0.0.1 - - [01/Mar/2025 13:14:20] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:14:31] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:14:42] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:14:53] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:04] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:15] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:26] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:37] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:48] "GET /api/studies/9?after=9 HTTP/1.1" 200 278870
# 127.0.0.1 - - [01/Mar/2025 13:15:59] "GET /api/studies/9?after=9 HTTP/1.1" 200 1397987
# 127.0.0.1 - - [01/Mar/2025 13:15:59] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:16:03,159 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309f89660>
# 2025-03-01 13:16:03,162 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309032440>, 325605.532503416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309f89db0>
# 127.0.0.1 - - [01/Mar/2025 13:16:10] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 2025-03-01 13:16:14,956 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3091be9e0>
# 2025-03-01 13:16:14,958 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbc2080>, 325617.326167041)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3091bf070>
# 127.0.0.1 - - [01/Mar/2025 13:16:21] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:16:32] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:16:43] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:16:54] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:17:05] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:17:16] "GET /api/studies/9?after=10 HTTP/1.1" 200 278875
# 127.0.0.1 - - [01/Mar/2025 13:17:27] "GET /api/studies/9?after=10 HTTP/1.1" 200 280912
# 127.0.0.1 - - [01/Mar/2025 13:17:38] "GET /api/studies/9?after=10 HTTP/1.1" 200 1220666
# 127.0.0.1 - - [01/Mar/2025 13:17:38] "GET /api/studies/9/param_importances HTTP/1.1" 200 1424
# 2025-03-01 13:17:39,826 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a901c0>
# 2025-03-01 13:17:39,827 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309f873a0>, 325702.196987791)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a91c60>
# 127.0.0.1 - - [01/Mar/2025 13:17:49] "GET /api/studies/9?after=11 HTTP/1.1" 200 278841
# 2025-03-01 13:17:51,973 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3087eb0a0>
# 2025-03-01 13:17:51,975 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309f85c00>, 325714.344913083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3087eb790>
# 127.0.0.1 - - [01/Mar/2025 13:18:00] "GET /api/studies/9?after=11 HTTP/1.1" 200 278841
# 127.0.0.1 - - [01/Mar/2025 13:18:11] "GET /api/studies/9?after=11 HTTP/1.1" 200 278841
# 127.0.0.1 - - [01/Mar/2025 13:18:22] "GET /api/studies/9?after=11 HTTP/1.1" 200 278841
# 127.0.0.1 - - [01/Mar/2025 13:18:33] "GET /api/studies/9?after=11 HTTP/1.1" 200 278841
# 127.0.0.1 - - [01/Mar/2025 13:18:44] "GET /api/studies/9?after=11 HTTP/1.1" 200 743405
# 127.0.0.1 - - [01/Mar/2025 13:18:44] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:18:51,326 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309981570>
# 2025-03-01 13:18:51,327 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309b86c20>, 325773.702042416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309981030>
# 127.0.0.1 - - [01/Mar/2025 13:18:55] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 2025-03-01 13:19:03,400 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a29f7f0>
# 2025-03-01 13:19:03,401 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309b86c20>, 325785.774502833)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a29c2e0>
# 127.0.0.1 - - [01/Mar/2025 13:19:06] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 127.0.0.1 - - [01/Mar/2025 13:19:17] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 127.0.0.1 - - [01/Mar/2025 13:19:28] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 127.0.0.1 - - [01/Mar/2025 13:19:39] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 127.0.0.1 - - [01/Mar/2025 13:19:50] "GET /api/studies/9?after=12 HTTP/1.1" 200 278873
# 127.0.0.1 - - [01/Mar/2025 13:20:01] "GET /api/studies/9?after=12 HTTP/1.1" 200 759317
# 127.0.0.1 - - [01/Mar/2025 13:20:01] "GET /api/studies/9/param_importances HTTP/1.1" 200 1430
# 2025-03-01 13:20:04,785 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f973670>
# 2025-03-01 13:20:04,787 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbc0e80>, 325847.159929375)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f971c00>
# 127.0.0.1 - - [01/Mar/2025 13:20:12] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 2025-03-01 13:20:16,730 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3090390c0>
# 2025-03-01 13:20:16,733 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbc0a00>, 325859.103686958)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fb1a260>
# 127.0.0.1 - - [01/Mar/2025 13:20:23] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:20:34] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:20:45] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:20:56] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:21:07] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:21:18] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:21:29] "GET /api/studies/9?after=13 HTTP/1.1" 200 278845
# 127.0.0.1 - - [01/Mar/2025 13:21:40] "GET /api/studies/9?after=13 HTTP/1.1" 200 1189110
# 127.0.0.1 - - [01/Mar/2025 13:21:40] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:21:48,055 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309e231f0>
# 2025-03-01 13:21:48,057 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309b86980>, 325950.431023291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309e22e00>
# 127.0.0.1 - - [01/Mar/2025 13:21:51] "GET /api/studies/9?after=14 HTTP/1.1" 200 278903
# 2025-03-01 13:22:01,497 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309478040>
# 2025-03-01 13:22:01,499 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x308c9dea0>, 325963.871619)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14d486410>
# 127.0.0.1 - - [01/Mar/2025 13:22:02] "GET /api/studies/9?after=14 HTTP/1.1" 200 278903
# 127.0.0.1 - - [01/Mar/2025 13:22:13] "GET /api/studies/9?after=14 HTTP/1.1" 200 278903
# 127.0.0.1 - - [01/Mar/2025 13:22:25] "GET /api/studies/9?after=14 HTTP/1.1" 200 278903
# 127.0.0.1 - - [01/Mar/2025 13:22:35] "GET /api/studies/9?after=14 HTTP/1.1" 200 497153
# 127.0.0.1 - - [01/Mar/2025 13:22:35] "GET /api/studies/9/param_importances HTTP/1.1" 200 1426
# 2025-03-01 13:22:41,609 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3086e8ee0>
# 2025-03-01 13:22:41,616 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f1bc0a0>, 326003.984081333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3086e8b80>
# 127.0.0.1 - - [01/Mar/2025 13:22:46] "GET /api/studies/9?after=15 HTTP/1.1" 200 252498
# 2025-03-01 13:22:54,209 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3086e9a20>
# 2025-03-01 13:22:54,211 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f9290c0>, 326016.58750875)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3086ea530>
# 127.0.0.1 - - [01/Mar/2025 13:22:57] "GET /api/studies/9?after=15 HTTP/1.1" 200 252498
# 127.0.0.1 - - [01/Mar/2025 13:23:08] "GET /api/studies/9?after=15 HTTP/1.1" 200 252498
# 127.0.0.1 - - [01/Mar/2025 13:23:19] "GET /api/studies/9?after=15 HTTP/1.1" 200 252498
# 127.0.0.1 - - [01/Mar/2025 13:23:30] "GET /api/studies/9?after=15 HTTP/1.1" 200 510741
# 127.0.0.1 - - [01/Mar/2025 13:23:31] "GET /api/studies/9/param_importances HTTP/1.1" 200 1428
# 2025-03-01 13:23:32,565 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3086eab30>
# 2025-03-01 13:23:32,568 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x3092de380>, 326054.947314208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3086ea110>
# 127.0.0.1 - - [01/Mar/2025 13:23:41] "GET /api/studies/9?after=16 HTTP/1.1" 200 252496
# 2025-03-01 13:23:44,498 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309f89b40>
# 2025-03-01 13:23:44,501 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x3092df760>, 326066.881700125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309f88df0>
# 127.0.0.1 - - [01/Mar/2025 13:23:52] "GET /api/studies/9?after=16 HTTP/1.1" 200 252496
# 127.0.0.1 - - [01/Mar/2025 13:24:04] "GET /api/studies/9?after=16 HTTP/1.1" 200 252496
# 127.0.0.1 - - [01/Mar/2025 13:24:14] "GET /api/studies/9?after=16 HTTP/1.1" 200 544350
# 127.0.0.1 - - [01/Mar/2025 13:24:14] "GET /api/studies/9/param_importances HTTP/1.1" 200 1427
# 2025-03-01 13:24:24,922 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x308df4bb0>
# 2025-03-01 13:24:24,924 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326107.308548625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x11f03fa30>
# 127.0.0.1 - - [01/Mar/2025 13:24:25] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:24:36] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 2025-03-01 13:24:36,845 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x308df7b20>
# 2025-03-01 13:24:36,846 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326119.234004125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x308df6b00>
# 127.0.0.1 - - [01/Mar/2025 13:24:47] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:24:58] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:25:09] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:25:20] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:25:31] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:25:42] "GET /api/studies/9?after=17 HTTP/1.1" 200 252560
# 127.0.0.1 - - [01/Mar/2025 13:25:53] "GET /api/studies/9?after=17 HTTP/1.1" 200 1548683
# 127.0.0.1 - - [01/Mar/2025 13:25:53] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:25:56,459 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x177b0d3f0>
# 2025-03-01 13:25:56,462 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326198.843405333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f971fc0>
# 127.0.0.1 - - [01/Mar/2025 13:26:04] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 2025-03-01 13:26:08,162 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x308df65c0>
# 2025-03-01 13:26:08,164 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326210.551589708)])']
# connector: <aiohttp.connector.TCPConnector object at 0x308df4f40>
# 127.0.0.1 - - [01/Mar/2025 13:26:15] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:26:26] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:26:37] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:26:48] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:26:59] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:27:10] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:27:21] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:27:32] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:27:43] "GET /api/studies/9?after=18 HTTP/1.1" 200 778292
# 127.0.0.1 - - [01/Mar/2025 13:27:54] "GET /api/studies/9?after=18 HTTP/1.1" 200 1826204
# 127.0.0.1 - - [01/Mar/2025 13:27:54] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:27:55,917 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x308df77c0>
# 2025-03-01 13:27:55,918 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326318.305318958)])']
# connector: <aiohttp.connector.TCPConnector object at 0x308df42e0>
# 127.0.0.1 - - [01/Mar/2025 13:28:05] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 2025-03-01 13:28:07,649 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309855ab0>
# 2025-03-01 13:28:07,651 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326330.039258291)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309857e80>
# 127.0.0.1 - - [01/Mar/2025 13:28:16] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:28:27] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:28:38] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:28:49] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:00] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:11] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:22] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:33] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:44] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:29:55] "GET /api/studies/9?after=19 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:30:06] "GET /api/studies/9?after=19 HTTP/1.1" 200 2013401
# 127.0.0.1 - - [01/Mar/2025 13:30:06] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:30:16,941 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x177f3c160>
# 2025-03-01 13:30:16,951 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f1bc0a0>, 326459.319670333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x177f3d540>
# 127.0.0.1 - - [01/Mar/2025 13:30:17] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:30:28] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 2025-03-01 13:30:28,892 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a55bbe0>
# 2025-03-01 13:30:28,899 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f5033a0>, 326471.282393)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a55bee0>
# 127.0.0.1 - - [01/Mar/2025 13:30:39] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:30:50] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:31:01] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:31:12] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:31:23] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:31:34] "GET /api/studies/9?after=20 HTTP/1.1" 200 778296
# 127.0.0.1 - - [01/Mar/2025 13:31:45] "GET /api/studies/9?after=20 HTTP/1.1" 200 1561721
# 127.0.0.1 - - [01/Mar/2025 13:31:45] "GET /api/studies/9/param_importances HTTP/1.1" 200 1425
# 2025-03-01 13:31:50,859 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309982980>
# 2025-03-01 13:31:50,860 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14fbd1720>, 326553.249741208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309981c30>
# 127.0.0.1 - - [01/Mar/2025 13:31:56] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 2025-03-01 13:32:02,749 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a92b00>
# 2025-03-01 13:32:02,751 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92b640>, 326565.13916)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a91360>
# 127.0.0.1 - - [01/Mar/2025 13:32:07] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:32:18] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:32:29] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:32:40] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:32:51] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:33:02] "GET /api/studies/9?after=21 HTTP/1.1" 200 784813
# 127.0.0.1 - - [01/Mar/2025 13:33:13] "GET /api/studies/9?after=21 HTTP/1.1" 200 1568079
# 127.0.0.1 - - [01/Mar/2025 13:33:13] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:33:21,599 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309f188e0>
# 2025-03-01 13:33:21,602 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92b640>, 326643.988914375)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309f18070>
# 127.0.0.1 - - [01/Mar/2025 13:33:24] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 2025-03-01 13:33:33,340 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309ff56f0>
# 2025-03-01 13:33:33,342 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92b640>, 326655.73168125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309ff7af0>
# 127.0.0.1 - - [01/Mar/2025 13:33:35] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:33:46] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:33:57] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:34:08] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:34:19] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:34:30] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:34:41] "GET /api/studies/9?after=22 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:34:52] "GET /api/studies/9?after=22 HTTP/1.1" 200 1534193
# 127.0.0.1 - - [01/Mar/2025 13:34:52] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:34:54,353 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14fa295d0>
# 2025-03-01 13:34:54,363 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92b640>, 326736.744337416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14fa28ca0>
# 127.0.0.1 - - [01/Mar/2025 13:35:03] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 2025-03-01 13:35:06,488 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x177b0ea10>
# 2025-03-01 13:35:06,489 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f92b640>, 326748.88049925)])']
# connector: <aiohttp.connector.TCPConnector object at 0x177b0d9c0>
# 127.0.0.1 - - [01/Mar/2025 13:35:14] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:35:25] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:35:36] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:35:47] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:35:58] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:36:09] "GET /api/studies/9?after=23 HTTP/1.1" 200 787978
# 127.0.0.1 - - [01/Mar/2025 13:36:20] "GET /api/studies/9?after=23 HTTP/1.1" 200 1646780
# 127.0.0.1 - - [01/Mar/2025 13:36:20] "GET /api/studies/9/param_importances HTTP/1.1" 200 1419
# 2025-03-01 13:36:29,741 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a64070>
# 2025-03-01 13:36:29,743 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309964dc0>, 326832.135213208)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a64760>
# 127.0.0.1 - - [01/Mar/2025 13:36:31] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 2025-03-01 13:36:41,623 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30987c5e0>
# 2025-03-01 13:36:41,627 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 326844.008559083)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30987ca90>
# 127.0.0.1 - - [01/Mar/2025 13:36:42] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:36:53] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:04] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:15] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:26] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:37] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:48] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:37:59] "GET /api/studies/9?after=24 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:38:10] "GET /api/studies/9?after=24 HTTP/1.1" 200 1801815
# 127.0.0.1 - - [01/Mar/2025 13:38:10] "GET /api/studies/9/param_importances HTTP/1.1" 200 1421
# 2025-03-01 13:38:21,300 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f2da380>
# 2025-03-01 13:38:21,315 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 326943.694301333)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f2da1a0>
# 127.0.0.1 - - [01/Mar/2025 13:38:21] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:38:32] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 2025-03-01 13:38:33,351 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309980520>
# 2025-03-01 13:38:33,352 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 326955.749831958)])']
# connector: <aiohttp.connector.TCPConnector object at 0x177aeba90>
# 127.0.0.1 - - [01/Mar/2025 13:38:43] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:38:54] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:39:05] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:39:16] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:39:27] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:39:38] "GET /api/studies/9?after=25 HTTP/1.1" 200 787976
# 127.0.0.1 - - [01/Mar/2025 13:39:49] "GET /api/studies/9?after=25 HTTP/1.1" 200 1575553
# 127.0.0.1 - - [01/Mar/2025 13:39:50] "GET /api/studies/9/param_importances HTTP/1.1" 200 1419
# 2025-03-01 13:39:52,574 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f2da4a0>
# 2025-03-01 13:39:52,578 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 327034.933295666)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f2db820>
# 127.0.0.1 - - [01/Mar/2025 13:40:00] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 2025-03-01 13:40:04,426 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a922c0>
# 2025-03-01 13:40:04,428 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 327046.783503)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a90730>
# 127.0.0.1 - - [01/Mar/2025 13:40:11] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:40:22] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:40:33] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:40:44] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:40:55] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:41:06] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:41:18] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:41:28] "GET /api/studies/9?after=26 HTTP/1.1" 200 787948
# 127.0.0.1 - - [01/Mar/2025 13:41:39] "GET /api/studies/9?after=26 HTTP/1.1" 200 1903834
# 127.0.0.1 - - [01/Mar/2025 13:41:40] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:41:44,302 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x30a29f8b0>
# 2025-03-01 13:41:44,304 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x14f929660>, 327146.664311125)])']
# connector: <aiohttp.connector.TCPConnector object at 0x30a29e1a0>
# 127.0.0.1 - - [01/Mar/2025 13:41:50] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 2025-03-01 13:41:56,027 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309283190>
# 2025-03-01 13:41:56,030 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x30a1a32e0>, 327158.387017958)])']
# connector: <aiohttp.connector.TCPConnector object at 0x3092821a0>
# 127.0.0.1 - - [01/Mar/2025 13:42:01] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:42:12] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:42:23] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:42:34] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:42:45] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:42:56] "GET /api/studies/9?after=27 HTTP/1.1" 200 788004
# 127.0.0.1 - - [01/Mar/2025 13:43:07] "GET /api/studies/9?after=27 HTTP/1.1" 200 1579050
# 127.0.0.1 - - [01/Mar/2025 13:43:07] "GET /api/studies/9/param_importances HTTP/1.1" 200 1416
# 127.0.0.1 - - [01/Mar/2025 13:43:17] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 2025-03-01 13:43:18,171 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a325c0>
# 2025-03-01 13:43:18,172 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x309f86aa0>, 327240.538292708)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a33f40>
# 127.0.0.1 - - [01/Mar/2025 13:43:27] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 2025-03-01 13:43:29,969 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a30250>
# 2025-03-01 13:43:29,973 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x3092de9e0>, 327252.323978541)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a33f40>
# 127.0.0.1 - - [01/Mar/2025 13:43:39] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:43:49] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:44:00] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:44:11] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:44:22] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:44:33] "GET /api/studies/9?after=28 HTTP/1.1" 200 788008
# 127.0.0.1 - - [01/Mar/2025 13:44:44] "GET /api/studies/9?after=28 HTTP/1.1" 200 1554744
# 127.0.0.1 - - [01/Mar/2025 13:44:45] "GET /api/studies/9/param_importances HTTP/1.1" 200 1423
# 2025-03-01 13:44:54,632 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a93ee0>
# 2025-03-01 13:44:54,636 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x30a1a1d20>, 327336.980182625)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a909a0>
# 127.0.0.1 - - [01/Mar/2025 13:44:55] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 2025-03-01 13:45:06,573 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x309a92e90>
# 2025-03-01 13:45:06,576 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x30a1a1a20>, 327348.930610416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x309a902b0>
# 127.0.0.1 - - [01/Mar/2025 13:45:06] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:45:18] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:45:29] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:45:40] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:45:51] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:46:02] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:46:13] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:46:24] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:46:36] "GET /api/studies/9?after=29 HTTP/1.1" 200 787946
# 127.0.0.1 - - [01/Mar/2025 13:46:46] "GET /api/studies/9?after=29 HTTP/1.1" 200 1931724
# 127.0.0.1 - - [01/Mar/2025 13:46:46] "GET /api/studies/9/param_importances HTTP/1.1" 200 1419
# 2025-03-01 13:46:57,329 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x14f9ffaf0>
# 2025-03-01 13:46:57,334 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x3092dc7c0>, 327459.692795416)])']
# connector: <aiohttp.connector.TCPConnector object at 0x14f9fccd0>
# 127.0.0.1 - - [01/Mar/2025 13:46:57] "GET /api/studies/9?after=30 HTTP/1.1" 200 787944
# 127.0.0.1 - - [01/Mar/2025 13:47:08] "GET /api/studies/9?after=30 HTTP/1.1" 200 787944
# 2025-03-01 13:47:09,288 - asyncio - ERROR - Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x3099f1ab0>
# 2025-03-01 13:47:09,289 - asyncio - ERROR - Unclosed connector
# connections: ['deque([(<aiohttp.client_proto.ResponseHandler object at 0x3092dd8a0>, 327471.651911708)])']
# ...
# optuna.exceptions.StorageInternalError: An exception is raised during the commit. This typically happens due to invalid data in the commit, e.g. exceeding max length.
# Error in _optimize_async: An exception is raised during the commit. This typically happens due to invalid data in the commit, e.g. exceeding max length.
# 127.0.0.1 - - [02/Mar/2025 10:18:51] "GET /api/studies/9?after=1367 HTTP/1.1" 200 267819
# 127.0.0.1 - - [02/Mar/2025 10:18:51] "GET /api/studies/9?after=1367 HTTP/1.1" 200 267819
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1094, in Connection._commit_impl(self, autocommit)
#    1093 try:
# -> 1094     self.engine.dialect.do_commit(self.connection)
#    1095 except BaseException as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/default.py:686, in DefaultDialect.do_commit(self, dbapi_connection)
#     685 def do_commit(self, dbapi_connection):
# --> 686     dbapi_connection.commit()
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:77, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      76     yield session
# ---> 77     session.commit()
#      78 except sqlalchemy_exc.IntegrityError as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1454, in Session.commit(self)
#    1452         raise sa_exc.InvalidRequestError("No transaction is begun.")
# -> 1454 self._transaction.commit(_to_root=self.future)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/orm/session.py:839, in SessionTransaction.commit(self, _to_root)
#     838     if should_commit:
# --> 839         trans.commit()
#     841 self._state = COMMITTED
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2469, in Transaction.commit(self)
#    2468 try:
# -> 2469     self._do_commit()
#    2470 finally:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2659, in RootTransaction._do_commit(self)
#    2658 try:
# -> 2659     self._connection_commit_impl()
#    2660 finally:
#    2661     # whether or not commit succeeds, cancel any
#    2662     # nested transactions, make this transaction "inactive"
#    2663     # and remove it as a reset agent
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2630, in RootTransaction._connection_commit_impl(self)
#    2629 def _connection_commit_impl(self):
# -> 2630     self.connection._commit_impl()
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1096, in Connection._commit_impl(self, autocommit)
#    1095 except BaseException as e:
# -> 1096     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2134, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2133 elif should_wrap:
# -> 2134     util.raise_(
#    2135         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136     )
#    2137 else:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1094, in Connection._commit_impl(self, autocommit)
#    1093 try:
# -> 1094     self.engine.dialect.do_commit(self.connection)
#    1095 except BaseException as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/default.py:686, in DefaultDialect.do_commit(self, dbapi_connection)
#     685 def do_commit(self, dbapi_connection):
# --> 686     dbapi_connection.commit()
#
# OperationalError: (sqlite3.OperationalError) database is locked
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# StorageInternalError                      Traceback (most recent call last)
# File ~/quants-lab/core/backtesting/optimizer.py:259, in StrategyOptimizer._optimize_async(self, study, config_generator, n_trials)
#     258     # Report the result back to the study
# --> 259     study.tell(trial, value)
#     261 except Exception as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/study/study.py:657, in Study.tell(self, trial, values, state, skip_if_finished)
#     580 """Finish a trial created with :func:`~optuna.study.Study.ask`.
#     581
#     582 .. seealso::
#    (...)
#     654     A returned trial is deep copied thus user can modify it as needed.
#     655 """
# --> 657 return _tell_with_warning(
#     658     study=self,
#     659     trial=trial,
#     660     value_or_values=values,
#     661     state=state,
#     662     skip_if_finished=skip_if_finished,
#     663 )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/study/_tell.py:181, in _tell_with_warning(study, trial, value_or_values, state, skip_if_finished, suppress_warning)
#     180 finally:
# --> 181     study._storage.set_trial_state_values(frozen_trial._trial_id, state, values)
#     183 frozen_trial = copy.deepcopy(study._storage.get_trial(frozen_trial._trial_id))
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:187, in _CachedStorage.set_trial_state_values(self, trial_id, state, values)
#     184 def set_trial_state_values(
#     185     self, trial_id: int, state: TrialState, values: Sequence[float] | None = None
#     186 ) -> bool:
# --> 187     return self._backend.set_trial_state_values(trial_id, state=state, values=values)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:638, in RDBStorage.set_trial_state_values(self, trial_id, state, values)
#     637 try:
# --> 638     with _create_scoped_session(self.scoped_session) as session:
#     639         trial = models.TrialModel.find_or_raise_by_id(trial_id, session, for_update=True)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     141 try:
# --> 142     next(self.gen)
#     143 except StopIteration:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:94, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      89     message = (
#      90         "An exception is raised during the commit. "
#      91         "This typically happens due to invalid data in the commit, "
#      92         "e.g. exceeding max length. "
#      93     )
# ---> 94     raise optuna.exceptions.StorageInternalError(message) from e
#      95 except Exception:
#
# StorageInternalError: An exception is raised during the commit. This typically happens due to invalid data in the commit, e.g. exceeding max length.
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1094, in Connection._commit_impl(self, autocommit)
#    1093 try:
# -> 1094     self.engine.dialect.do_commit(self.connection)
#    1095 except BaseException as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/default.py:686, in DefaultDialect.do_commit(self, dbapi_connection)
#     685 def do_commit(self, dbapi_connection):
# --> 686     dbapi_connection.commit()
#
# OperationalError: database is locked
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:77, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      76     yield session
# ---> 77     session.commit()
#      78 except sqlalchemy_exc.IntegrityError as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/orm/session.py:1454, in Session.commit(self)
#    1452         raise sa_exc.InvalidRequestError("No transaction is begun.")
# -> 1454 self._transaction.commit(_to_root=self.future)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/orm/session.py:839, in SessionTransaction.commit(self, _to_root)
#     838     if should_commit:
# --> 839         trans.commit()
#     841 self._state = COMMITTED
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2469, in Transaction.commit(self)
#    2468 try:
# -> 2469     self._do_commit()
#    2470 finally:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2659, in RootTransaction._do_commit(self)
#    2658 try:
# -> 2659     self._connection_commit_impl()
#    2660 finally:
#    2661     # whether or not commit succeeds, cancel any
#    2662     # nested transactions, make this transaction "inactive"
#    2663     # and remove it as a reset agent
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2630, in RootTransaction._connection_commit_impl(self)
#    2629 def _connection_commit_impl(self):
# -> 2630     self.connection._commit_impl()
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1096, in Connection._commit_impl(self, autocommit)
#    1095 except BaseException as e:
# -> 1096     self._handle_dbapi_exception(e, None, None, None, None)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2134, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2133 elif should_wrap:
# -> 2134     util.raise_(
#    2135         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2136     )
#    2137 else:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/util/compat.py:211, in raise_(***failed resolving arguments***)
#     210 try:
# --> 211     raise exception
#     212 finally:
#     213     # credit to
#     214     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     215     # as the __traceback__ object creates a cycle
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1094, in Connection._commit_impl(self, autocommit)
#    1093 try:
# -> 1094     self.engine.dialect.do_commit(self.connection)
#    1095 except BaseException as e:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/sqlalchemy/engine/default.py:686, in DefaultDialect.do_commit(self, dbapi_connection)
#     685 def do_commit(self, dbapi_connection):
# --> 686     dbapi_connection.commit()
#
# OperationalError: (sqlite3.OperationalError) database is locked
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# StorageInternalError                      Traceback (most recent call last)
# Cell In[7], line 8
#       5 optimizer.launch_optuna_dashboard()
#       7 # Run the optimization
# ----> 8 await optimizer.optimize(
#       9     study_name=f"new_oro3_optimization",
#      10     config_generator=config_generator,
#      11     n_trials=5000,
#      12 )
#      13 optimizer.get_study_best_params(f"new_oro3_optimization")
#
# File ~/quants-lab/core/backtesting/optimizer.py:226, in StrategyOptimizer.optimize(self, study_name, config_generator, n_trials, load_if_exists)
#     224 study = self._create_study(study_name, load_if_exists=load_if_exists)
#     225 logger.info("About to start optimizing...")
# --> 226 await self._optimize_async(study, config_generator, n_trials=n_trials)
#
# File ~/quants-lab/core/backtesting/optimizer.py:263, in StrategyOptimizer._optimize_async(self, study, config_generator, n_trials)
#     261 except Exception as e:
#     262     print(f"Error in _optimize_async: {str(e)}")
# --> 263     study.tell(trial, state=optuna.trial.TrialState.FAIL)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/study/study.py:657, in Study.tell(self, trial, values, state, skip_if_finished)
#     573 def tell(
#     574     self,
#     575     trial: Trial | int,
#    (...)
#     578     skip_if_finished: bool = False,
#     579 ) -> FrozenTrial:
#     580     """Finish a trial created with :func:`~optuna.study.Study.ask`.
#     581
#     582     .. seealso::
#    (...)
#     654         A returned trial is deep copied thus user can modify it as needed.
#     655     """
# --> 657     return _tell_with_warning(
#     658         study=self,
#     659         trial=trial,
#     660         value_or_values=values,
#     661         state=state,
#     662         skip_if_finished=skip_if_finished,
#     663     )
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/study/_tell.py:181, in _tell_with_warning(study, trial, value_or_values, state, skip_if_finished, suppress_warning)
#     179     study.sampler.after_trial(study, frozen_trial, state, values)
#     180 finally:
# --> 181     study._storage.set_trial_state_values(frozen_trial._trial_id, state, values)
#     183 frozen_trial = copy.deepcopy(study._storage.get_trial(frozen_trial._trial_id))
#     185 if warning_message is not None:
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_cached_storage.py:187, in _CachedStorage.set_trial_state_values(self, trial_id, state, values)
#     184 def set_trial_state_values(
#     185     self, trial_id: int, state: TrialState, values: Sequence[float] | None = None
#     186 ) -> bool:
# --> 187     return self._backend.set_trial_state_values(trial_id, state=state, values=values)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:638, in RDBStorage.set_trial_state_values(self, trial_id, state, values)
#     634 def set_trial_state_values(
#     635     self, trial_id: int, state: TrialState, values: Sequence[float] | None = None
#     636 ) -> bool:
#     637     try:
# --> 638         with _create_scoped_session(self.scoped_session) as session:
#     639             trial = models.TrialModel.find_or_raise_by_id(trial_id, session, for_update=True)
#     640             self.check_trial_is_updatable(trial_id, trial.state)
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/contextlib.py:142, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     140 if typ is None:
#     141     try:
# --> 142         next(self.gen)
#     143     except StopIteration:
#     144         return False
#
# File /opt/anaconda3/envs/quants-lab/lib/python3.10/site-packages/optuna/storages/_rdb/storage.py:94, in _create_scoped_session(scoped_session, ignore_integrity_error)
#      88     session.rollback()
#      89     message = (
#      90         "An exception is raised during the commit. "
#      91         "This typically happens due to invalid data in the commit, "
#      92         "e.g. exceeding max length. "
#      93     )
# ---> 94     raise optuna.exceptions.StorageInternalError(message) from e
#      95 except Exception:
#      96     session.rollback()
#
# StorageInternalError: An exception is raised during the commit. This typically happens due to invalid data in the commit, e.g. exceeding max length.
# 127.0.0.1 - - [02/Mar/2025 10:19:02] "GET /api/studies/9?after=1367 HTTP/1.1" 200 267819
# 127.0.0.1 - - [02/Mar/2025 10:19:11] "GET /api/studies/9?after=1368 HTTP/1.1" 200 264364
# 127.0.0.1 - - [02/Mar/2025 10:19:11] "GET /api/studies/9?after=1368 HTTP/1.1" 200 264364
